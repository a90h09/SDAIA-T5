# %% [markdown]
# # Continuous Bag of Words (CBOW) Model

# %% [markdown]
# In this exam, we will create a CBOW model using a sample Arabic traffic corpus. The corpus consists of sentences describing various traffic scenarios. The goal of the CBOW model is to predict a target word based on its surrounding context words.

# %% [markdown]
# # Importing Required Libraries

# %% [markdown]
# In this step, we import the necessary libraries to build and train the Continuous Bag of Words (CBOW) model.
#
# - **TensorFlow and Keras**: Used to build the neural network model, including the layers like `Embedding`, `Dense`, and `Lambda`.
# - **Tokenizer**: A utility from Keras for tokenizing and processing text data.
# - **NumPy**: Used for handling numerical operations, particularly for processing arrays and data manipulation.
#
# These libraries will provide the essential tools for text preprocessing and model development in the upcoming steps.
#
# Add more if needed!

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, Lambda
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Preparing the Corpus

# %% [markdown]
# In this step, we initialize the corpus that will be used for training the Continuous Bag of Words (CBOW) model. The corpus consists of Arabic sentences, each of which describes different traffic scenarios.
#
# - **Corpus**: A collection of traffic-related sentences in Arabic.
#
# This step sets up the text data that we will use in the upcoming stages of tokenization and model training.

# %%
corpus = [
    "الطريق مزدحم اليوم بسبب الحادث المروري الذي حدث صباحاً ويؤدي إلى تأخير كبير في الوصول",
    "كان الطريق مزدحما للغاية والسيارات متوقفة تقريباً نتيجة الازدحام الشديد والحركة بطيئة جداً ولا تتحسن",
    "أنا أحب الذهاب إلى السوق في الصباح الباكر لتفادي الازدحام وشراء الخضروات الطازجة دون الانتظار في الطريق",
    "السيارات بطيئة بسبب الازدحام المروري في الشارع الرئيسي والتأخير في حركة المرور خلال ساعات الذروة",
    "هناك ازدحام مروري في الشارع بسبب أعمال البناء والحفريات التي تعطل حركة السيارات وتتسبب في تأخير كبير",
    "ازدحام السيارات يزداد في المساء عندما يبدأ الجميع بالعودة إلى منازلهم من العمل وتتوقف حركة المرور بالكامل",
    "الطريق السريع يشهد ازدحاما مستمرا خلال فترة الظهيرة بسبب الشاحنات الكبيرة التي تبطئ حركة السير",
    "الحافلات والسيارات عالقة في الازدحام المروري في المنطقة التجارية مما يؤدي إلى تأخير وصول الناس إلى وجهاتهم",
    "حركة المرور مزدحمة اليوم بسبب الفعاليات التي تقام في وسط المدينة مما يزيد من صعوبة الوصول إلى هناك",
    "كان من الصعب جدا القيادة على الطريق الرئيسي اليوم بسبب الازدحام الخانق الذي استمر طوال اليوم",
    "الطريق إلى المطار مزدحم اليوم بسبب الحوادث المتكررة والتأخيرات الكبيرة في حركة المرور على الطريق السريع",
    "الشارع مزدحم بالسيارات والحافلات الكبيرة مما يجعل التنقل بطيئًا جدًا ويزيد من وقت الوصول إلى العمل",
    "ازدحام السيارات في المدينة أصبح مشكلة كبيرة خاصة خلال ساعات الذروة حيث يصعب التحرك بسرعة",
    "تفاقم الازدحام في الطرق الجانبية بسبب إغلاق الطريق الرئيسي المؤدي إلى وسط المدينة لصيانة الجسر",
    "ازدحام مروري خانق يواجه السكان يوميًا خلال تنقلهم من وإلى العمل على الطرق السريعة المؤدية إلى المدينة",
    "التأخيرات المرورية اليوم ناجمة عن سوء الأحوال الجوية والضباب الذي يعيق الرؤية ويبطئ حركة السيارات",
    "حوادث السير المتكررة على الطريق الزراعي تؤدي إلى ازدحام مروري شديد وتأخير كبير في وصول السيارات",
    "كانت حركة السير اليوم غير منتظمة بسبب تنظيم حدث رياضي كبير أدى إلى إغلاق بعض الشوارع الرئيسية",
    "الأعمال الإنشائية في الشارع الرئيسي تسببت في اختناق مروري كامل وتباطؤ في حركة السيارات خلال النهار",
    "تراكم السيارات عند تقاطع الطرق الرئيسية أدى إلى ازدحام شديد وزيادة كبيرة في مدة الانتظار للوصول إلى الجهة المطلوبة"
]

# %% [markdown]
# # Defining Vocabulary and Model Parameters

# %% [markdown]
# In this step, we define key parameters that will be used to configure the CBOW model.
#
# - **Vocabulary size**: We calculate the size of the vocabulary based on the number of unique words in the corpus. The `vocab_size` represents the total number of unique tokens (words) in the dataset plus one for padding.
#
# - **Embedding size**: The `embedding_size` defines the dimensionality of the word embeddings. In this case, we set the embedding size to 10, meaning each word will be represented as a 10-dimensional vector in the embedding layer.
#
# - **Window size**: The `window_size` defines how many words to the left and right of the target word are considered as context. Here, a window size of 2 means that two words before and two words after the target word will be used as context.
#
# These parameters will play an essential role in shaping the CBOW model architecture.

# %% [markdown]
# ### ^ Same as above

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)
sequences = tokenizer.texts_to_sequences(corpus)

# %%
vocab_size = len(tokenizer.word_index) + 1
embedding_size = 10
window_size = 2

# %% [markdown]
# # Preparing Context-Target Pairs for CBOW

# %% [markdown]
# In this step, we generate the context-target pairs from the tokenized sequences to train the CBOW model.
#
# - **Context words**: For each word in a sequence, the surrounding words (within the window size) are considered as context. The context consists of the words immediately before and after the target word.
#
# - **Target word**: The word in the middle of the context window is treated as the target word that the model will learn to predict.
#
# We iterate through each sequence, collecting the context words and corresponding target words:
# - For each word in a sequence, we gather the surrounding words based on the defined window size.
# - The middle word is the target, and the surrounding words form the context.
#
# Finally:
# - **`X`**: An array of context words.
# - **`y`**: The target words are one-hot encoded, which means they are converted into a categorical format where each word is represented as a vector of length equal to the vocabulary size.
#
# These context-target pairs will be used to train the CBOW model to predict a target word based on its context.

# %% [markdown]
# ## ^ same as above

# %%
contexts = []
targets = []

for sequence in sequences:
    for i in range(window_size, len(sequence) - window_size):
        context = sequence[i - window_size:i] + sequence[i + 1:i + window_size + 1]
        target = sequence[i]
        contexts.append(context)
        targets.append(target)

X = np.array(contexts)
y = to_categorical(targets, num_classes=vocab_size)

# %% [markdown]
# # Building and Training the CBOW Model

# %% [markdown]
# In this step, we build and train the Continuous Bag of Words (CBOW) model using the context-target pairs created earlier.
#
# 1. **Model architecture**:
#    - **Embedding layer**: This layer transforms the input context words into dense vector representations (embeddings) of size defined by `embedding_size`. The `input_dim` is set to the vocabulary size, and the `input_length` is twice the window size (since context consists of words from both sides of the target).
#
#    - **Lambda layer**: This layer computes the mean of the context word embeddings. It averages the embeddings of the context words to generate a single representation that will be used to predict the target word.
#
#    - **Dense layer**: This fully connected layer outputs a probability distribution over the vocabulary, using the softmax activation function. It predicts the most likely target word based on the context word embeddings.
#
# 2. **Compilation**:
#    The model is compiled using the Adam optimizer and categorical cross-entropy as the loss function, which is suitable for multi-class classification tasks. Accuracy is used as a metric to evaluate the model's performance during training.
#
# 3. **Training the model**:
#    The model is trained on the context-target pairs for 500 epochs. During each epoch, the model learns to predict the target word based on the context, refining its weights to improve accuracy.
#
# 4. **Saving the model weights**:
#    After training, the model weights are saved to a file (`cbow_model.weights.h5`) for future use. This allows us to load the trained model later without retraining.
#
# By the end of this step, the CBOW model will have learned to predict target words based on their surrounding context from the given corpus.

# %%
model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=embedding_size, input_length=2*window_size))
model.add(Lambda(lambda x: tf.reduce_mean(x, axis=1)))
model.add(Dense(units=vocab_size, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X, y, epochs=500, validation_split=0.2)
# Out:
# Epoch 1/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.0000e+00 - loss: 5.1875 - val_accuracy: 0.0000e+00 - val_loss: 5.1883
# Epoch 2/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0247 - loss: 5.1824 - val_accuracy: 0.0408 - val_loss: 5.1887
# Epoch 3/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0474 - loss: 5.1778 - val_accuracy: 0.0408 - val_loss: 5.1894
# Epoch 4/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0727 - loss: 5.1729 - val_accuracy: 0.0612 - val_loss: 5.1900
# Epoch 5/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0864 - loss: 5.1688 - val_accuracy: 0.0816 - val_loss: 5.1907
# Epoch 6/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0777 - loss: 5.1641 - val_accuracy: 0.0816 - val_loss: 5.1915
# Epoch 7/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0885 - loss: 5.1597 - val_accuracy: 0.0816 - val_loss: 5.1922
# Epoch 8/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0938 - loss: 5.1545 - val_accuracy: 0.0816 - val_loss: 5.1930
# Epoch 9/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1119 - loss: 5.1499 - val_accuracy: 0.0816 - val_loss: 5.1937
# Epoch 10/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0878 - loss: 5.1468 - val_accuracy: 0.0816 - val_loss: 5.1946
# Epoch 11/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1057 - loss: 5.1410 - val_accuracy: 0.0816 - val_loss: 5.1954
# Epoch 12/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1037 - loss: 5.1361 - val_accuracy: 0.0816 - val_loss: 5.1963
# Epoch 13/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1042 - loss: 5.1304 - val_accuracy: 0.0816 - val_loss: 5.1970
# Epoch 14/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1022 - loss: 5.1243 - val_accuracy: 0.0816 - val_loss: 5.1980
# Epoch 15/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1210 - loss: 5.1183 - val_accuracy: 0.0816 - val_loss: 5.1990
# Epoch 16/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0968 - loss: 5.1119 - val_accuracy: 0.0816 - val_loss: 5.1998
# Epoch 17/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1252 - loss: 5.1050 - val_accuracy: 0.0816 - val_loss: 5.2006
# Epoch 18/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1333 - loss: 5.1013 - val_accuracy: 0.0816 - val_loss: 5.2017
# Epoch 19/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0842 - loss: 5.0969 - val_accuracy: 0.0816 - val_loss: 5.2029
# Epoch 20/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1013 - loss: 5.0892 - val_accuracy: 0.0816 - val_loss: 5.2040
# Epoch 21/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1288 - loss: 5.0799 - val_accuracy: 0.0816 - val_loss: 5.2052
# Epoch 22/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1355 - loss: 5.0744 - val_accuracy: 0.0816 - val_loss: 5.2063
# Epoch 23/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1077 - loss: 5.0634 - val_accuracy: 0.0816 - val_loss: 5.2074
# Epoch 24/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1092 - loss: 5.0541 - val_accuracy: 0.0816 - val_loss: 5.2086
# Epoch 25/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1378 - loss: 5.0450 - val_accuracy: 0.0816 - val_loss: 5.2099
# Epoch 26/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1784 - loss: 5.0350 - val_accuracy: 0.0816 - val_loss: 5.2114
# Epoch 27/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1463 - loss: 5.0330 - val_accuracy: 0.0816 - val_loss: 5.2133
# Epoch 28/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1420 - loss: 5.0242 - val_accuracy: 0.0816 - val_loss: 5.2152
# Epoch 29/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1259 - loss: 5.0125 - val_accuracy: 0.0816 - val_loss: 5.2174
# Epoch 30/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1388 - loss: 4.9966 - val_accuracy: 0.0816 - val_loss: 5.2196
# Epoch 31/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1427 - loss: 4.9914 - val_accuracy: 0.0816 - val_loss: 5.2219
# Epoch 32/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1498 - loss: 4.9776 - val_accuracy: 0.0816 - val_loss: 5.2243
# Epoch 33/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1568 - loss: 4.9697 - val_accuracy: 0.0816 - val_loss: 5.2269
# Epoch 34/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1472 - loss: 4.9618 - val_accuracy: 0.0816 - val_loss: 5.2294
# Epoch 35/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1275 - loss: 4.9469 - val_accuracy: 0.0816 - val_loss: 5.2320
# Epoch 36/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1391 - loss: 4.9376 - val_accuracy: 0.0816 - val_loss: 5.2346
# Epoch 37/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1541 - loss: 4.9154 - val_accuracy: 0.0816 - val_loss: 5.2373
# Epoch 38/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1289 - loss: 4.9112 - val_accuracy: 0.0816 - val_loss: 5.2398
# Epoch 39/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1751 - loss: 4.8904 - val_accuracy: 0.0816 - val_loss: 5.2427
# Epoch 40/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1672 - loss: 4.8807 - val_accuracy: 0.0816 - val_loss: 5.2460
# Epoch 41/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1563 - loss: 4.8690 - val_accuracy: 0.0816 - val_loss: 5.2496
# Epoch 42/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1521 - loss: 4.8568 - val_accuracy: 0.0816 - val_loss: 5.2535
# Epoch 43/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1439 - loss: 4.8409 - val_accuracy: 0.0816 - val_loss: 5.2574
# Epoch 44/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1595 - loss: 4.8168 - val_accuracy: 0.0816 - val_loss: 5.2611
# Epoch 45/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1410 - loss: 4.8067 - val_accuracy: 0.0816 - val_loss: 5.2649
# Epoch 46/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1482 - loss: 4.7961 - val_accuracy: 0.0816 - val_loss: 5.2689
# Epoch 47/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1575 - loss: 4.7750 - val_accuracy: 0.0816 - val_loss: 5.2730
# Epoch 48/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1384 - loss: 4.7610 - val_accuracy: 0.0816 - val_loss: 5.2773
# Epoch 49/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1395 - loss: 4.7316 - val_accuracy: 0.0816 - val_loss: 5.2815
# Epoch 50/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1420 - loss: 4.7326 - val_accuracy: 0.0816 - val_loss: 5.2858
# Epoch 51/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1426 - loss: 4.7068 - val_accuracy: 0.1020 - val_loss: 5.2906
# Epoch 52/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1407 - loss: 4.6870 - val_accuracy: 0.1020 - val_loss: 5.2951
# Epoch 53/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1518 - loss: 4.6867 - val_accuracy: 0.1020 - val_loss: 5.3001
# Epoch 54/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1330 - loss: 4.6741 - val_accuracy: 0.1020 - val_loss: 5.3050
# Epoch 55/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1398 - loss: 4.6357 - val_accuracy: 0.1020 - val_loss: 5.3095
# Epoch 56/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1411 - loss: 4.6252 - val_accuracy: 0.1020 - val_loss: 5.3142
# Epoch 57/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1219 - loss: 4.6132 - val_accuracy: 0.1020 - val_loss: 5.3193
# Epoch 58/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1245 - loss: 4.6099 - val_accuracy: 0.1020 - val_loss: 5.3243
# Epoch 59/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1688 - loss: 4.5805 - val_accuracy: 0.1020 - val_loss: 5.3292
# Epoch 60/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1341 - loss: 4.5752 - val_accuracy: 0.1020 - val_loss: 5.3341
# Epoch 61/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1465 - loss: 4.5656 - val_accuracy: 0.1020 - val_loss: 5.3394
# Epoch 62/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1532 - loss: 4.4918 - val_accuracy: 0.1020 - val_loss: 5.3446
# Epoch 63/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1331 - loss: 4.5413 - val_accuracy: 0.1020 - val_loss: 5.3495
# Epoch 64/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1305 - loss: 4.5277 - val_accuracy: 0.1020 - val_loss: 5.3539
# Epoch 65/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1430 - loss: 4.4731 - val_accuracy: 0.1020 - val_loss: 5.3585
# Epoch 66/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1590 - loss: 4.4717 - val_accuracy: 0.1020 - val_loss: 5.3635
# Epoch 67/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1096 - loss: 4.4512 - val_accuracy: 0.1020 - val_loss: 5.3683
# Epoch 68/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1111 - loss: 4.4417 - val_accuracy: 0.1020 - val_loss: 5.3732
# Epoch 69/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1148 - loss: 4.4318 - val_accuracy: 0.1020 - val_loss: 5.3788
# Epoch 70/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1521 - loss: 4.4087 - val_accuracy: 0.1020 - val_loss: 5.3837
# Epoch 71/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1457 - loss: 4.3919 - val_accuracy: 0.1020 - val_loss: 5.3885
# Epoch 72/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1593 - loss: 4.3790 - val_accuracy: 0.1020 - val_loss: 5.3921
# Epoch 73/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1664 - loss: 4.3592 - val_accuracy: 0.1020 - val_loss: 5.3963
# Epoch 74/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1384 - loss: 4.3391 - val_accuracy: 0.1020 - val_loss: 5.4011
# Epoch 75/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1292 - loss: 4.3528 - val_accuracy: 0.1020 - val_loss: 5.4059
# Epoch 76/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1603 - loss: 4.3215 - val_accuracy: 0.1020 - val_loss: 5.4111
# Epoch 77/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1560 - loss: 4.2959 - val_accuracy: 0.1020 - val_loss: 5.4162
# Epoch 78/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1558 - loss: 4.3021 - val_accuracy: 0.1020 - val_loss: 5.4202
# Epoch 79/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.1438 - loss: 4.2718 - val_accuracy: 0.1020 - val_loss: 5.4245
# Epoch 80/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1357 - loss: 4.2675 - val_accuracy: 0.1020 - val_loss: 5.4295
# Epoch 81/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1777 - loss: 4.2249 - val_accuracy: 0.1020 - val_loss: 5.4344
# Epoch 82/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1669 - loss: 4.1887 - val_accuracy: 0.1020 - val_loss: 5.4387
# Epoch 83/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1465 - loss: 4.2371 - val_accuracy: 0.1020 - val_loss: 5.4431
# Epoch 84/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1407 - loss: 4.1917 - val_accuracy: 0.1020 - val_loss: 5.4470
# Epoch 85/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1683 - loss: 4.1884 - val_accuracy: 0.1020 - val_loss: 5.4511
# Epoch 86/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1397 - loss: 4.2030 - val_accuracy: 0.1020 - val_loss: 5.4553
# Epoch 87/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1566 - loss: 4.1264 - val_accuracy: 0.1020 - val_loss: 5.4597
# Epoch 88/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1780 - loss: 4.1393 - val_accuracy: 0.1020 - val_loss: 5.4642
# Epoch 89/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.1887 - loss: 4.1185 - val_accuracy: 0.1020 - val_loss: 5.4686
# Epoch 90/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1992 - loss: 4.0934 - val_accuracy: 0.1020 - val_loss: 5.4731
# Epoch 91/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.1840 - loss: 4.0826 - val_accuracy: 0.1020 - val_loss: 5.4777
# Epoch 92/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1495 - loss: 4.1045 - val_accuracy: 0.1020 - val_loss: 5.4827
# Epoch 93/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1569 - loss: 4.0733 - val_accuracy: 0.1020 - val_loss: 5.4876
# Epoch 94/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1695 - loss: 4.0161 - val_accuracy: 0.1020 - val_loss: 5.4926
# Epoch 95/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1680 - loss: 4.0157 - val_accuracy: 0.1020 - val_loss: 5.4971
# Epoch 96/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1970 - loss: 3.9944 - val_accuracy: 0.1020 - val_loss: 5.5011
# Epoch 97/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1856 - loss: 4.0038 - val_accuracy: 0.1020 - val_loss: 5.5055
# Epoch 98/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1681 - loss: 4.0003 - val_accuracy: 0.1020 - val_loss: 5.5097
# Epoch 99/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1663 - loss: 4.0366 - val_accuracy: 0.1020 - val_loss: 5.5134
# Epoch 100/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1870 - loss: 3.9414 - val_accuracy: 0.1020 - val_loss: 5.5172
# Epoch 101/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1669 - loss: 3.9380 - val_accuracy: 0.1020 - val_loss: 5.5216
# Epoch 102/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1439 - loss: 3.9584 - val_accuracy: 0.1020 - val_loss: 5.5254
# Epoch 103/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1844 - loss: 3.9285 - val_accuracy: 0.1020 - val_loss: 5.5299
# Epoch 104/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1772 - loss: 3.8945 - val_accuracy: 0.1020 - val_loss: 5.5345
# Epoch 105/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2042 - loss: 3.8860 - val_accuracy: 0.1020 - val_loss: 5.5385
# Epoch 106/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1655 - loss: 3.8610 - val_accuracy: 0.1020 - val_loss: 5.5427
# Epoch 107/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1622 - loss: 3.9196 - val_accuracy: 0.1020 - val_loss: 5.5462
# Epoch 108/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1849 - loss: 3.8536 - val_accuracy: 0.1020 - val_loss: 5.5495
# Epoch 109/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1758 - loss: 3.8036 - val_accuracy: 0.1020 - val_loss: 5.5525
# Epoch 110/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1676 - loss: 3.8242 - val_accuracy: 0.1020 - val_loss: 5.5561
# Epoch 111/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1461 - loss: 3.8159 - val_accuracy: 0.1020 - val_loss: 5.5595
# Epoch 112/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2071 - loss: 3.7731 - val_accuracy: 0.1020 - val_loss: 5.5630
# Epoch 113/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1718 - loss: 3.8247 - val_accuracy: 0.1020 - val_loss: 5.5660
# Epoch 114/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1484 - loss: 3.8051 - val_accuracy: 0.1020 - val_loss: 5.5693
# Epoch 115/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1746 - loss: 3.7957 - val_accuracy: 0.1020 - val_loss: 5.5731
# Epoch 116/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1607 - loss: 3.7324 - val_accuracy: 0.1020 - val_loss: 5.5766
# Epoch 117/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1763 - loss: 3.7307 - val_accuracy: 0.1020 - val_loss: 5.5796
# Epoch 118/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.1898 - loss: 3.7415 - val_accuracy: 0.1020 - val_loss: 5.5813
# Epoch 119/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1565 - loss: 3.7398 - val_accuracy: 0.1020 - val_loss: 5.5836
# Epoch 120/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1886 - loss: 3.7013 - val_accuracy: 0.1020 - val_loss: 5.5866
# Epoch 121/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1872 - loss: 3.6976 - val_accuracy: 0.1020 - val_loss: 5.5897
# Epoch 122/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1829 - loss: 3.6762 - val_accuracy: 0.1020 - val_loss: 5.5927
# Epoch 123/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1608 - loss: 3.6863 - val_accuracy: 0.1020 - val_loss: 5.5960
# Epoch 124/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1796 - loss: 3.6654 - val_accuracy: 0.1020 - val_loss: 5.5990
# Epoch 125/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1631 - loss: 3.6556 - val_accuracy: 0.1020 - val_loss: 5.6022
# Epoch 126/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1576 - loss: 3.6905 - val_accuracy: 0.1020 - val_loss: 5.6054
# Epoch 127/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1972 - loss: 3.6079 - val_accuracy: 0.1020 - val_loss: 5.6088
# Epoch 128/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2028 - loss: 3.6202 - val_accuracy: 0.1020 - val_loss: 5.6116
# Epoch 129/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1925 - loss: 3.5574 - val_accuracy: 0.1020 - val_loss: 5.6147
# Epoch 130/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1892 - loss: 3.5855 - val_accuracy: 0.1020 - val_loss: 5.6172
# Epoch 131/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1518 - loss: 3.5914 - val_accuracy: 0.1020 - val_loss: 5.6195
# Epoch 132/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2166 - loss: 3.5407 - val_accuracy: 0.1020 - val_loss: 5.6218
# Epoch 133/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2002 - loss: 3.5268 - val_accuracy: 0.1020 - val_loss: 5.6236
# Epoch 134/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2060 - loss: 3.5524 - val_accuracy: 0.1020 - val_loss: 5.6254
# Epoch 135/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1986 - loss: 3.5142 - val_accuracy: 0.1020 - val_loss: 5.6274
# Epoch 136/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2023 - loss: 3.4744 - val_accuracy: 0.1020 - val_loss: 5.6293
# Epoch 137/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2288 - loss: 3.4405 - val_accuracy: 0.1020 - val_loss: 5.6310
# Epoch 138/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2194 - loss: 3.4650 - val_accuracy: 0.1020 - val_loss: 5.6333
# Epoch 139/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2018 - loss: 3.4752 - val_accuracy: 0.1020 - val_loss: 5.6353
# Epoch 140/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2104 - loss: 3.4909 - val_accuracy: 0.1020 - val_loss: 5.6376
# Epoch 141/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.2597 - loss: 3.4029 - val_accuracy: 0.1020 - val_loss: 5.6393
# Epoch 142/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.2444 - loss: 3.4244 - val_accuracy: 0.1020 - val_loss: 5.6415
# Epoch 143/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2388 - loss: 3.4202 - val_accuracy: 0.1020 - val_loss: 5.6431
# Epoch 144/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2233 - loss: 3.4310 - val_accuracy: 0.1020 - val_loss: 5.6447
# Epoch 145/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2263 - loss: 3.4278 - val_accuracy: 0.1020 - val_loss: 5.6465
# Epoch 146/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2231 - loss: 3.3854 - val_accuracy: 0.1020 - val_loss: 5.6488
# Epoch 147/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2779 - loss: 3.3575 - val_accuracy: 0.1020 - val_loss: 5.6521
# Epoch 148/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2383 - loss: 3.3302 - val_accuracy: 0.1020 - val_loss: 5.6547
# Epoch 149/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2496 - loss: 3.3197 - val_accuracy: 0.1020 - val_loss: 5.6569
# Epoch 150/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2358 - loss: 3.4033 - val_accuracy: 0.1020 - val_loss: 5.6585
# Epoch 151/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2644 - loss: 3.3152 - val_accuracy: 0.1020 - val_loss: 5.6602
# Epoch 152/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2151 - loss: 3.3833 - val_accuracy: 0.1020 - val_loss: 5.6617
# Epoch 153/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2701 - loss: 3.2907 - val_accuracy: 0.1020 - val_loss: 5.6631
# Epoch 154/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2128 - loss: 3.3591 - val_accuracy: 0.1020 - val_loss: 5.6644
# Epoch 155/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2509 - loss: 3.3399 - val_accuracy: 0.1020 - val_loss: 5.6661
# Epoch 156/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2687 - loss: 3.2616 - val_accuracy: 0.1020 - val_loss: 5.6684
# Epoch 157/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2772 - loss: 3.2434 - val_accuracy: 0.1020 - val_loss: 5.6694
# Epoch 158/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2619 - loss: 3.2358 - val_accuracy: 0.1020 - val_loss: 5.6702
# Epoch 159/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2672 - loss: 3.1870 - val_accuracy: 0.1020 - val_loss: 5.6717
# Epoch 160/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3010 - loss: 3.2217 - val_accuracy: 0.1020 - val_loss: 5.6730
# Epoch 161/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2762 - loss: 3.2201 - val_accuracy: 0.1020 - val_loss: 5.6740
# Epoch 162/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2543 - loss: 3.2595 - val_accuracy: 0.1020 - val_loss: 5.6759
# Epoch 163/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3002 - loss: 3.1632 - val_accuracy: 0.1020 - val_loss: 5.6774
# Epoch 164/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2714 - loss: 3.2009 - val_accuracy: 0.1020 - val_loss: 5.6788
# Epoch 165/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3100 - loss: 3.1610 - val_accuracy: 0.1020 - val_loss: 5.6807
# Epoch 166/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2533 - loss: 3.2107 - val_accuracy: 0.1020 - val_loss: 5.6828
# Epoch 167/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2605 - loss: 3.1732 - val_accuracy: 0.1020 - val_loss: 5.6847
# Epoch 168/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2969 - loss: 3.1061 - val_accuracy: 0.1020 - val_loss: 5.6867
# Epoch 169/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2854 - loss: 3.1207 - val_accuracy: 0.1020 - val_loss: 5.6887
# Epoch 170/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2899 - loss: 3.1007 - val_accuracy: 0.1020 - val_loss: 5.6904
# Epoch 171/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2789 - loss: 3.0906 - val_accuracy: 0.1020 - val_loss: 5.6920
# Epoch 172/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2771 - loss: 3.1315 - val_accuracy: 0.1020 - val_loss: 5.6937
# Epoch 173/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2801 - loss: 3.0744 - val_accuracy: 0.1020 - val_loss: 5.6951
# Epoch 174/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3039 - loss: 3.0593 - val_accuracy: 0.1020 - val_loss: 5.6971
# Epoch 175/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3083 - loss: 3.0362 - val_accuracy: 0.1020 - val_loss: 5.6992
# Epoch 176/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3295 - loss: 3.0089 - val_accuracy: 0.1020 - val_loss: 5.7001
# Epoch 177/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2767 - loss: 3.0417 - val_accuracy: 0.1020 - val_loss: 5.7009
# Epoch 178/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2891 - loss: 3.0247 - val_accuracy: 0.1020 - val_loss: 5.7019
# Epoch 179/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3111 - loss: 3.0248 - val_accuracy: 0.1020 - val_loss: 5.7032
# Epoch 180/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.2991 - loss: 3.0311 - val_accuracy: 0.1020 - val_loss: 5.7050
# Epoch 181/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3019 - loss: 3.0253 - val_accuracy: 0.1020 - val_loss: 5.7066
# Epoch 182/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2993 - loss: 2.9921 - val_accuracy: 0.1020 - val_loss: 5.7079
# Epoch 183/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3043 - loss: 3.0048 - val_accuracy: 0.1020 - val_loss: 5.7085
# Epoch 184/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3305 - loss: 2.9293 - val_accuracy: 0.1020 - val_loss: 5.7097
# Epoch 185/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3248 - loss: 2.9399 - val_accuracy: 0.1020 - val_loss: 5.7104
# Epoch 186/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3258 - loss: 2.9506 - val_accuracy: 0.1020 - val_loss: 5.7120
# Epoch 187/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3561 - loss: 2.9432 - val_accuracy: 0.1020 - val_loss: 5.7139
# Epoch 188/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3328 - loss: 2.9821 - val_accuracy: 0.1020 - val_loss: 5.7158
# Epoch 189/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3467 - loss: 2.9746 - val_accuracy: 0.1020 - val_loss: 5.7178
# Epoch 190/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3928 - loss: 2.8535 - val_accuracy: 0.1020 - val_loss: 5.7206
# Epoch 191/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4118 - loss: 2.8286 - val_accuracy: 0.1020 - val_loss: 5.7220
# Epoch 192/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3300 - loss: 2.9251 - val_accuracy: 0.1020 - val_loss: 5.7238
# Epoch 193/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3631 - loss: 2.8579 - val_accuracy: 0.1020 - val_loss: 5.7255
# Epoch 194/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3843 - loss: 2.8383 - val_accuracy: 0.1020 - val_loss: 5.7267
# Epoch 195/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3520 - loss: 2.8751 - val_accuracy: 0.1020 - val_loss: 5.7275
# Epoch 196/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3564 - loss: 2.8835 - val_accuracy: 0.1020 - val_loss: 5.7287
# Epoch 197/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3536 - loss: 2.8436 - val_accuracy: 0.1020 - val_loss: 5.7301
# Epoch 198/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3572 - loss: 2.8215 - val_accuracy: 0.1020 - val_loss: 5.7309
# Epoch 199/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4181 - loss: 2.8086 - val_accuracy: 0.1020 - val_loss: 5.7318
# Epoch 200/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3789 - loss: 2.8245 - val_accuracy: 0.1020 - val_loss: 5.7326
# Epoch 201/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3835 - loss: 2.7917 - val_accuracy: 0.1020 - val_loss: 5.7341
# Epoch 202/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3933 - loss: 2.8138 - val_accuracy: 0.1020 - val_loss: 5.7353
# Epoch 203/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3626 - loss: 2.8011 - val_accuracy: 0.1020 - val_loss: 5.7367
# Epoch 204/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3600 - loss: 2.7983 - val_accuracy: 0.0816 - val_loss: 5.7380
# Epoch 205/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4025 - loss: 2.6881 - val_accuracy: 0.0816 - val_loss: 5.7394
# Epoch 206/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4027 - loss: 2.7271 - val_accuracy: 0.0816 - val_loss: 5.7407
# Epoch 207/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4114 - loss: 2.7350 - val_accuracy: 0.0816 - val_loss: 5.7419
# Epoch 208/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3926 - loss: 2.7644 - val_accuracy: 0.0816 - val_loss: 5.7435
# Epoch 209/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4046 - loss: 2.7701 - val_accuracy: 0.0816 - val_loss: 5.7452
# Epoch 210/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4267 - loss: 2.6430 - val_accuracy: 0.0816 - val_loss: 5.7469
# Epoch 211/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3941 - loss: 2.6939 - val_accuracy: 0.0816 - val_loss: 5.7485
# Epoch 212/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3692 - loss: 2.7315 - val_accuracy: 0.0816 - val_loss: 5.7502
# Epoch 213/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3773 - loss: 2.6934 - val_accuracy: 0.0816 - val_loss: 5.7518
# Epoch 214/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3767 - loss: 2.7251 - val_accuracy: 0.0816 - val_loss: 5.7531
# Epoch 215/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3864 - loss: 2.7045 - val_accuracy: 0.0816 - val_loss: 5.7544
# Epoch 216/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3832 - loss: 2.6902 - val_accuracy: 0.0816 - val_loss: 5.7560
# Epoch 217/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3970 - loss: 2.6503 - val_accuracy: 0.0816 - val_loss: 5.7575
# Epoch 218/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3843 - loss: 2.7003 - val_accuracy: 0.0816 - val_loss: 5.7591
# Epoch 219/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4222 - loss: 2.6069 - val_accuracy: 0.0816 - val_loss: 5.7607
# Epoch 220/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3740 - loss: 2.6308 - val_accuracy: 0.0816 - val_loss: 5.7625
# Epoch 221/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4126 - loss: 2.6151 - val_accuracy: 0.0816 - val_loss: 5.7641
# Epoch 222/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3728 - loss: 2.6189 - val_accuracy: 0.0816 - val_loss: 5.7660
# Epoch 223/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4262 - loss: 2.6256 - val_accuracy: 0.0816 - val_loss: 5.7675
# Epoch 224/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4171 - loss: 2.5607 - val_accuracy: 0.0816 - val_loss: 5.7686
# Epoch 225/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3795 - loss: 2.6055 - val_accuracy: 0.0816 - val_loss: 5.7692
# Epoch 226/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3940 - loss: 2.5824 - val_accuracy: 0.0816 - val_loss: 5.7702
# Epoch 227/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3910 - loss: 2.5735 - val_accuracy: 0.0816 - val_loss: 5.7712
# Epoch 228/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3837 - loss: 2.5848 - val_accuracy: 0.0816 - val_loss: 5.7725
# Epoch 229/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3994 - loss: 2.5413 - val_accuracy: 0.0816 - val_loss: 5.7737
# Epoch 230/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4329 - loss: 2.4959 - val_accuracy: 0.0816 - val_loss: 5.7753
# Epoch 231/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4010 - loss: 2.5444 - val_accuracy: 0.0816 - val_loss: 5.7765
# Epoch 232/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3935 - loss: 2.5654 - val_accuracy: 0.0816 - val_loss: 5.7781
# Epoch 233/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3421 - loss: 2.6035 - val_accuracy: 0.0816 - val_loss: 5.7796
# Epoch 234/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4036 - loss: 2.5284 - val_accuracy: 0.0816 - val_loss: 5.7814
# Epoch 235/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4151 - loss: 2.5217 - val_accuracy: 0.0816 - val_loss: 5.7833
# Epoch 236/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4642 - loss: 2.4677 - val_accuracy: 0.0816 - val_loss: 5.7850
# Epoch 237/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4232 - loss: 2.4455 - val_accuracy: 0.0816 - val_loss: 5.7863
# Epoch 238/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4577 - loss: 2.4298 - val_accuracy: 0.0816 - val_loss: 5.7871
# Epoch 239/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4318 - loss: 2.4313 - val_accuracy: 0.0816 - val_loss: 5.7882
# Epoch 240/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4392 - loss: 2.4614 - val_accuracy: 0.0816 - val_loss: 5.7897
# Epoch 241/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4275 - loss: 2.4420 - val_accuracy: 0.0816 - val_loss: 5.7911
# Epoch 242/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4123 - loss: 2.4525 - val_accuracy: 0.0816 - val_loss: 5.7927
# Epoch 243/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4655 - loss: 2.4216 - val_accuracy: 0.0816 - val_loss: 5.7943
# Epoch 244/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4858 - loss: 2.3841 - val_accuracy: 0.0816 - val_loss: 5.7962
# Epoch 245/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4998 - loss: 2.3595 - val_accuracy: 0.0816 - val_loss: 5.7977
# Epoch 246/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4861 - loss: 2.4275 - val_accuracy: 0.0816 - val_loss: 5.7985
# Epoch 247/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4848 - loss: 2.3561 - val_accuracy: 0.0816 - val_loss: 5.8001
# Epoch 248/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4697 - loss: 2.3553 - val_accuracy: 0.0816 - val_loss: 5.8014
# Epoch 249/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4466 - loss: 2.4262 - val_accuracy: 0.0816 - val_loss: 5.8032
# Epoch 250/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4913 - loss: 2.3541 - val_accuracy: 0.0816 - val_loss: 5.8051
# Epoch 251/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4670 - loss: 2.3822 - val_accuracy: 0.0816 - val_loss: 5.8069
# Epoch 252/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4825 - loss: 2.3548 - val_accuracy: 0.0816 - val_loss: 5.8084
# Epoch 253/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4671 - loss: 2.3207 - val_accuracy: 0.0816 - val_loss: 5.8101
# Epoch 254/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4985 - loss: 2.3203 - val_accuracy: 0.0816 - val_loss: 5.8120
# Epoch 255/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4614 - loss: 2.3631 - val_accuracy: 0.0816 - val_loss: 5.8137
# Epoch 256/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4813 - loss: 2.3421 - val_accuracy: 0.0816 - val_loss: 5.8151
# Epoch 257/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4545 - loss: 2.3754 - val_accuracy: 0.0816 - val_loss: 5.8169
# Epoch 258/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4928 - loss: 2.3212 - val_accuracy: 0.0816 - val_loss: 5.8184
# Epoch 259/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4737 - loss: 2.3160 - val_accuracy: 0.0816 - val_loss: 5.8205
# Epoch 260/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4975 - loss: 2.3133 - val_accuracy: 0.0816 - val_loss: 5.8224
# Epoch 261/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4867 - loss: 2.2766 - val_accuracy: 0.0816 - val_loss: 5.8250
# Epoch 262/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5086 - loss: 2.3204 - val_accuracy: 0.0816 - val_loss: 5.8268
# Epoch 263/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5080 - loss: 2.2840 - val_accuracy: 0.0816 - val_loss: 5.8282
# Epoch 264/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4926 - loss: 2.2573 - val_accuracy: 0.0816 - val_loss: 5.8297
# Epoch 265/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4979 - loss: 2.2837 - val_accuracy: 0.0816 - val_loss: 5.8323
# Epoch 266/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4958 - loss: 2.2518 - val_accuracy: 0.0816 - val_loss: 5.8350
# Epoch 267/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4414 - loss: 2.3076 - val_accuracy: 0.0816 - val_loss: 5.8369
# Epoch 268/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5253 - loss: 2.1736 - val_accuracy: 0.0816 - val_loss: 5.8391
# Epoch 269/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5398 - loss: 2.2072 - val_accuracy: 0.0816 - val_loss: 5.8414
# Epoch 270/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4956 - loss: 2.2399 - val_accuracy: 0.0816 - val_loss: 5.8433
# Epoch 271/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5341 - loss: 2.2102 - val_accuracy: 0.0816 - val_loss: 5.8449
# Epoch 272/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5488 - loss: 2.1645 - val_accuracy: 0.0816 - val_loss: 5.8463
# Epoch 273/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4864 - loss: 2.2337 - val_accuracy: 0.0816 - val_loss: 5.8476
# Epoch 274/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5059 - loss: 2.2152 - val_accuracy: 0.0816 - val_loss: 5.8489
# Epoch 275/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5156 - loss: 2.2030 - val_accuracy: 0.0816 - val_loss: 5.8503
# Epoch 276/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5174 - loss: 2.2109 - val_accuracy: 0.0816 - val_loss: 5.8520
# Epoch 277/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5048 - loss: 2.2245 - val_accuracy: 0.0816 - val_loss: 5.8540
# Epoch 278/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5123 - loss: 2.1913 - val_accuracy: 0.0816 - val_loss: 5.8557
# Epoch 279/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4813 - loss: 2.2114 - val_accuracy: 0.0816 - val_loss: 5.8576
# Epoch 280/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5261 - loss: 2.1257 - val_accuracy: 0.0816 - val_loss: 5.8597
# Epoch 281/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5220 - loss: 2.1324 - val_accuracy: 0.0816 - val_loss: 5.8613
# Epoch 282/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5658 - loss: 2.0409 - val_accuracy: 0.0816 - val_loss: 5.8627
# Epoch 283/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5530 - loss: 2.1120 - val_accuracy: 0.0816 - val_loss: 5.8624
# Epoch 284/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5323 - loss: 2.1125 - val_accuracy: 0.0816 - val_loss: 5.8625
# Epoch 285/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5290 - loss: 2.0930 - val_accuracy: 0.0816 - val_loss: 5.8639
# Epoch 286/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5262 - loss: 2.1194 - val_accuracy: 0.0816 - val_loss: 5.8665
# Epoch 287/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5404 - loss: 2.0686 - val_accuracy: 0.0816 - val_loss: 5.8688
# Epoch 288/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5436 - loss: 2.0950 - val_accuracy: 0.0816 - val_loss: 5.8713
# Epoch 289/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5470 - loss: 2.0793 - val_accuracy: 0.0816 - val_loss: 5.8737
# Epoch 290/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5556 - loss: 2.0853 - val_accuracy: 0.0816 - val_loss: 5.8760
# Epoch 291/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5471 - loss: 2.0667 - val_accuracy: 0.0816 - val_loss: 5.8767
# Epoch 292/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5441 - loss: 2.0944 - val_accuracy: 0.0816 - val_loss: 5.8777
# Epoch 293/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5211 - loss: 2.0443 - val_accuracy: 0.0816 - val_loss: 5.8788
# Epoch 294/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5290 - loss: 2.0971 - val_accuracy: 0.0816 - val_loss: 5.8789
# Epoch 295/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5301 - loss: 2.0619 - val_accuracy: 0.0816 - val_loss: 5.8802
# Epoch 296/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5928 - loss: 2.0006 - val_accuracy: 0.0816 - val_loss: 5.8821
# Epoch 297/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5825 - loss: 2.0104 - val_accuracy: 0.0816 - val_loss: 5.8832
# Epoch 298/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5463 - loss: 2.0118 - val_accuracy: 0.0816 - val_loss: 5.8845
# Epoch 299/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5115 - loss: 2.0527 - val_accuracy: 0.0816 - val_loss: 5.8862
# Epoch 300/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5459 - loss: 1.9848 - val_accuracy: 0.0816 - val_loss: 5.8881
# Epoch 301/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5726 - loss: 1.9644 - val_accuracy: 0.0816 - val_loss: 5.8904
# Epoch 302/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5350 - loss: 2.0341 - val_accuracy: 0.0816 - val_loss: 5.8921
# Epoch 303/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5518 - loss: 2.0081 - val_accuracy: 0.0816 - val_loss: 5.8936
# Epoch 304/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5434 - loss: 1.9982 - val_accuracy: 0.0816 - val_loss: 5.8949
# Epoch 305/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5318 - loss: 2.0176 - val_accuracy: 0.0816 - val_loss: 5.8961
# Epoch 306/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5675 - loss: 1.9728 - val_accuracy: 0.0816 - val_loss: 5.8976
# Epoch 307/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5624 - loss: 1.9170 - val_accuracy: 0.0816 - val_loss: 5.8997
# Epoch 308/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5194 - loss: 1.9936 - val_accuracy: 0.0816 - val_loss: 5.9022
# Epoch 309/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6039 - loss: 1.9106 - val_accuracy: 0.0816 - val_loss: 5.9047
# Epoch 310/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5749 - loss: 1.9352 - val_accuracy: 0.0816 - val_loss: 5.9069
# Epoch 311/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5909 - loss: 1.8841 - val_accuracy: 0.0816 - val_loss: 5.9095
# Epoch 312/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5256 - loss: 1.9971 - val_accuracy: 0.0816 - val_loss: 5.9123
# Epoch 313/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5851 - loss: 1.8993 - val_accuracy: 0.0816 - val_loss: 5.9152
# Epoch 314/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5307 - loss: 1.9681 - val_accuracy: 0.0816 - val_loss: 5.9182
# Epoch 315/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5986 - loss: 1.8955 - val_accuracy: 0.0816 - val_loss: 5.9211
# Epoch 316/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5649 - loss: 1.9246 - val_accuracy: 0.0816 - val_loss: 5.9235
# Epoch 317/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6036 - loss: 1.8435 - val_accuracy: 0.0816 - val_loss: 5.9257
# Epoch 318/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5807 - loss: 1.8626 - val_accuracy: 0.0816 - val_loss: 5.9279
# Epoch 319/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5335 - loss: 1.9354 - val_accuracy: 0.0816 - val_loss: 5.9298
# Epoch 320/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6144 - loss: 1.8394 - val_accuracy: 0.0816 - val_loss: 5.9317
# Epoch 321/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5737 - loss: 1.8591 - val_accuracy: 0.0816 - val_loss: 5.9335
# Epoch 322/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6086 - loss: 1.8490 - val_accuracy: 0.0816 - val_loss: 5.9354
# Epoch 323/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6140 - loss: 1.8208 - val_accuracy: 0.0816 - val_loss: 5.9373
# Epoch 324/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6239 - loss: 1.8073 - val_accuracy: 0.0816 - val_loss: 5.9389
# Epoch 325/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5919 - loss: 1.8299 - val_accuracy: 0.0816 - val_loss: 5.9411
# Epoch 326/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6131 - loss: 1.7878 - val_accuracy: 0.0816 - val_loss: 5.9436
# Epoch 327/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6426 - loss: 1.7817 - val_accuracy: 0.0816 - val_loss: 5.9452
# Epoch 328/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5931 - loss: 1.8454 - val_accuracy: 0.0816 - val_loss: 5.9471
# Epoch 329/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6182 - loss: 1.8063 - val_accuracy: 0.0816 - val_loss: 5.9491
# Epoch 330/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5989 - loss: 1.8606 - val_accuracy: 0.0816 - val_loss: 5.9513
# Epoch 331/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5926 - loss: 1.8451 - val_accuracy: 0.0816 - val_loss: 5.9534
# Epoch 332/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6038 - loss: 1.8087 - val_accuracy: 0.0816 - val_loss: 5.9559
# Epoch 333/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6004 - loss: 1.8342 - val_accuracy: 0.0816 - val_loss: 5.9587
# Epoch 334/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5912 - loss: 1.8285 - val_accuracy: 0.0816 - val_loss: 5.9612
# Epoch 335/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6267 - loss: 1.8132 - val_accuracy: 0.0816 - val_loss: 5.9631
# Epoch 336/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6519 - loss: 1.7550 - val_accuracy: 0.0816 - val_loss: 5.9649
# Epoch 337/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6106 - loss: 1.8248 - val_accuracy: 0.0816 - val_loss: 5.9662
# Epoch 338/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6255 - loss: 1.7823 - val_accuracy: 0.0816 - val_loss: 5.9683
# Epoch 339/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6162 - loss: 1.7567 - val_accuracy: 0.0816 - val_loss: 5.9705
# Epoch 340/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6065 - loss: 1.7692 - val_accuracy: 0.0816 - val_loss: 5.9731
# Epoch 341/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6173 - loss: 1.7694 - val_accuracy: 0.0816 - val_loss: 5.9760
# Epoch 342/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6309 - loss: 1.7411 - val_accuracy: 0.0816 - val_loss: 5.9787
# Epoch 343/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6135 - loss: 1.7448 - val_accuracy: 0.0816 - val_loss: 5.9813
# Epoch 344/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6309 - loss: 1.7407 - val_accuracy: 0.0816 - val_loss: 5.9837
# Epoch 345/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6465 - loss: 1.7064 - val_accuracy: 0.0816 - val_loss: 5.9858
# Epoch 346/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6492 - loss: 1.7006 - val_accuracy: 0.0816 - val_loss: 5.9878
# Epoch 347/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6452 - loss: 1.7267 - val_accuracy: 0.0816 - val_loss: 5.9899
# Epoch 348/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6083 - loss: 1.7358 - val_accuracy: 0.0816 - val_loss: 5.9921
# Epoch 349/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6407 - loss: 1.6789 - val_accuracy: 0.0816 - val_loss: 5.9943
# Epoch 350/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6681 - loss: 1.6686 - val_accuracy: 0.0816 - val_loss: 5.9965
# Epoch 351/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6670 - loss: 1.6567 - val_accuracy: 0.0816 - val_loss: 5.9990
# Epoch 352/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6475 - loss: 1.6687 - val_accuracy: 0.0816 - val_loss: 6.0017
# Epoch 353/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6595 - loss: 1.6669 - val_accuracy: 0.0816 - val_loss: 6.0040
# Epoch 354/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6217 - loss: 1.7031 - val_accuracy: 0.0816 - val_loss: 6.0063
# Epoch 355/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6489 - loss: 1.6624 - val_accuracy: 0.0816 - val_loss: 6.0088
# Epoch 356/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6227 - loss: 1.6450 - val_accuracy: 0.0816 - val_loss: 6.0109
# Epoch 357/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6445 - loss: 1.6352 - val_accuracy: 0.0816 - val_loss: 6.0135
# Epoch 358/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6433 - loss: 1.6638 - val_accuracy: 0.0816 - val_loss: 6.0153
# Epoch 359/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6576 - loss: 1.6483 - val_accuracy: 0.0816 - val_loss: 6.0174
# Epoch 360/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6350 - loss: 1.6397 - val_accuracy: 0.0816 - val_loss: 6.0194
# Epoch 361/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6306 - loss: 1.6537 - val_accuracy: 0.0816 - val_loss: 6.0214
# Epoch 362/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5897 - loss: 1.6700 - val_accuracy: 0.0816 - val_loss: 6.0236
# Epoch 363/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6638 - loss: 1.6005 - val_accuracy: 0.0816 - val_loss: 6.0252
# Epoch 364/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6331 - loss: 1.6455 - val_accuracy: 0.0816 - val_loss: 6.0271
# Epoch 365/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6467 - loss: 1.5865 - val_accuracy: 0.0816 - val_loss: 6.0293
# Epoch 366/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6579 - loss: 1.5582 - val_accuracy: 0.0816 - val_loss: 6.0313
# Epoch 367/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6636 - loss: 1.6148 - val_accuracy: 0.0816 - val_loss: 6.0330
# Epoch 368/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6774 - loss: 1.5548 - val_accuracy: 0.0816 - val_loss: 6.0337
# Epoch 369/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6498 - loss: 1.5863 - val_accuracy: 0.0816 - val_loss: 6.0354
# Epoch 370/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6481 - loss: 1.6234 - val_accuracy: 0.0816 - val_loss: 6.0383
# Epoch 371/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6543 - loss: 1.5886 - val_accuracy: 0.0816 - val_loss: 6.0410
# Epoch 372/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6646 - loss: 1.6020 - val_accuracy: 0.0816 - val_loss: 6.0427
# Epoch 373/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6824 - loss: 1.5564 - val_accuracy: 0.0816 - val_loss: 6.0448
# Epoch 374/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6861 - loss: 1.5373 - val_accuracy: 0.0816 - val_loss: 6.0476
# Epoch 375/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6895 - loss: 1.5324 - val_accuracy: 0.0816 - val_loss: 6.0501
# Epoch 376/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6637 - loss: 1.5983 - val_accuracy: 0.0816 - val_loss: 6.0521
# Epoch 377/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6807 - loss: 1.5571 - val_accuracy: 0.0816 - val_loss: 6.0543
# Epoch 378/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6642 - loss: 1.5578 - val_accuracy: 0.0816 - val_loss: 6.0564
# Epoch 379/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6944 - loss: 1.5392 - val_accuracy: 0.0816 - val_loss: 6.0585
# Epoch 380/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6860 - loss: 1.5286 - val_accuracy: 0.0816 - val_loss: 6.0607
# Epoch 381/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6846 - loss: 1.5511 - val_accuracy: 0.0816 - val_loss: 6.0640
# Epoch 382/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7064 - loss: 1.5058 - val_accuracy: 0.0816 - val_loss: 6.0669
# Epoch 383/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7077 - loss: 1.4973 - val_accuracy: 0.0816 - val_loss: 6.0702
# Epoch 384/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6843 - loss: 1.5084 - val_accuracy: 0.0816 - val_loss: 6.0731
# Epoch 385/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6999 - loss: 1.5192 - val_accuracy: 0.0816 - val_loss: 6.0754
# Epoch 386/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6936 - loss: 1.5057 - val_accuracy: 0.0816 - val_loss: 6.0779
# Epoch 387/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6991 - loss: 1.4959 - val_accuracy: 0.0816 - val_loss: 6.0805
# Epoch 388/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7187 - loss: 1.4607 - val_accuracy: 0.0816 - val_loss: 6.0831
# Epoch 389/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7064 - loss: 1.4663 - val_accuracy: 0.0816 - val_loss: 6.0861
# Epoch 390/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7144 - loss: 1.4698 - val_accuracy: 0.0816 - val_loss: 6.0883
# Epoch 391/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7283 - loss: 1.4459 - val_accuracy: 0.0816 - val_loss: 6.0905
# Epoch 392/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7249 - loss: 1.4394 - val_accuracy: 0.0816 - val_loss: 6.0929
# Epoch 393/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7186 - loss: 1.4475 - val_accuracy: 0.0816 - val_loss: 6.0953
# Epoch 394/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6932 - loss: 1.4551 - val_accuracy: 0.0816 - val_loss: 6.0976
# Epoch 395/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7394 - loss: 1.4208 - val_accuracy: 0.0816 - val_loss: 6.0999
# Epoch 396/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7073 - loss: 1.4055 - val_accuracy: 0.0816 - val_loss: 6.1021
# Epoch 397/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6957 - loss: 1.4683 - val_accuracy: 0.0816 - val_loss: 6.1044
# Epoch 398/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7222 - loss: 1.4213 - val_accuracy: 0.0816 - val_loss: 6.1066
# Epoch 399/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7091 - loss: 1.4228 - val_accuracy: 0.0816 - val_loss: 6.1088
# Epoch 400/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7368 - loss: 1.3919 - val_accuracy: 0.0816 - val_loss: 6.1106
# Epoch 401/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7107 - loss: 1.4543 - val_accuracy: 0.0816 - val_loss: 6.1130
# Epoch 402/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7092 - loss: 1.4075 - val_accuracy: 0.0816 - val_loss: 6.1160
# Epoch 403/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7026 - loss: 1.4252 - val_accuracy: 0.0816 - val_loss: 6.1185
# Epoch 404/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7215 - loss: 1.4222 - val_accuracy: 0.0816 - val_loss: 6.1205
# Epoch 405/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7276 - loss: 1.3908 - val_accuracy: 0.0816 - val_loss: 6.1228
# Epoch 406/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7070 - loss: 1.4031 - val_accuracy: 0.0816 - val_loss: 6.1252
# Epoch 407/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7300 - loss: 1.3762 - val_accuracy: 0.0816 - val_loss: 6.1280
# Epoch 408/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7099 - loss: 1.3783 - val_accuracy: 0.0816 - val_loss: 6.1312
# Epoch 409/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6841 - loss: 1.4457 - val_accuracy: 0.0816 - val_loss: 6.1337
# Epoch 410/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6998 - loss: 1.4065 - val_accuracy: 0.0816 - val_loss: 6.1365
# Epoch 411/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7204 - loss: 1.3638 - val_accuracy: 0.0816 - val_loss: 6.1398
# Epoch 412/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7589 - loss: 1.3489 - val_accuracy: 0.0816 - val_loss: 6.1427
# Epoch 413/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7087 - loss: 1.3668 - val_accuracy: 0.0816 - val_loss: 6.1455
# Epoch 414/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7128 - loss: 1.3698 - val_accuracy: 0.0816 - val_loss: 6.1477
# Epoch 415/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7456 - loss: 1.3158 - val_accuracy: 0.0816 - val_loss: 6.1502
# Epoch 416/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7284 - loss: 1.3307 - val_accuracy: 0.0816 - val_loss: 6.1530
# Epoch 417/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7410 - loss: 1.3406 - val_accuracy: 0.0816 - val_loss: 6.1557
# Epoch 418/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7496 - loss: 1.3375 - val_accuracy: 0.0816 - val_loss: 6.1583
# Epoch 419/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7460 - loss: 1.3319 - val_accuracy: 0.0816 - val_loss: 6.1613
# Epoch 420/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7471 - loss: 1.3057 - val_accuracy: 0.0816 - val_loss: 6.1640
# Epoch 421/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7469 - loss: 1.3540 - val_accuracy: 0.0816 - val_loss: 6.1667
# Epoch 422/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7421 - loss: 1.3062 - val_accuracy: 0.0816 - val_loss: 6.1695
# Epoch 423/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7174 - loss: 1.3358 - val_accuracy: 0.0816 - val_loss: 6.1720
# Epoch 424/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7725 - loss: 1.2616 - val_accuracy: 0.0816 - val_loss: 6.1744
# Epoch 425/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7337 - loss: 1.2862 - val_accuracy: 0.0816 - val_loss: 6.1773
# Epoch 426/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7234 - loss: 1.3038 - val_accuracy: 0.0816 - val_loss: 6.1794
# Epoch 427/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7311 - loss: 1.3090 - val_accuracy: 0.0816 - val_loss: 6.1816
# Epoch 428/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7349 - loss: 1.2987 - val_accuracy: 0.0816 - val_loss: 6.1843
# Epoch 429/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7467 - loss: 1.2705 - val_accuracy: 0.0816 - val_loss: 6.1878
# Epoch 430/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7206 - loss: 1.2998 - val_accuracy: 0.0816 - val_loss: 6.1906
# Epoch 431/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7077 - loss: 1.3097 - val_accuracy: 0.0816 - val_loss: 6.1942
# Epoch 432/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7689 - loss: 1.3045 - val_accuracy: 0.0816 - val_loss: 6.1973
# Epoch 433/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7423 - loss: 1.2670 - val_accuracy: 0.0816 - val_loss: 6.2004
# Epoch 434/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7545 - loss: 1.2864 - val_accuracy: 0.0816 - val_loss: 6.2037
# Epoch 435/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7687 - loss: 1.2425 - val_accuracy: 0.0816 - val_loss: 6.2064
# Epoch 436/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7490 - loss: 1.2784 - val_accuracy: 0.0816 - val_loss: 6.2091
# Epoch 437/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7794 - loss: 1.2409 - val_accuracy: 0.0816 - val_loss: 6.2113
# Epoch 438/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7647 - loss: 1.2167 - val_accuracy: 0.0816 - val_loss: 6.2134
# Epoch 439/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7809 - loss: 1.2107 - val_accuracy: 0.0816 - val_loss: 6.2156
# Epoch 440/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7400 - loss: 1.2845 - val_accuracy: 0.0816 - val_loss: 6.2183
# Epoch 441/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7551 - loss: 1.2500 - val_accuracy: 0.0816 - val_loss: 6.2210
# Epoch 442/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7821 - loss: 1.2165 - val_accuracy: 0.0816 - val_loss: 6.2237
# Epoch 443/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7401 - loss: 1.2684 - val_accuracy: 0.0816 - val_loss: 6.2263
# Epoch 444/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7622 - loss: 1.1987 - val_accuracy: 0.0816 - val_loss: 6.2287
# Epoch 445/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7663 - loss: 1.2043 - val_accuracy: 0.0816 - val_loss: 6.2314
# Epoch 446/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7522 - loss: 1.2333 - val_accuracy: 0.0816 - val_loss: 6.2342
# Epoch 447/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7888 - loss: 1.1693 - val_accuracy: 0.0816 - val_loss: 6.2367
# Epoch 448/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7499 - loss: 1.2127 - val_accuracy: 0.0816 - val_loss: 6.2389
# Epoch 449/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7931 - loss: 1.1667 - val_accuracy: 0.0816 - val_loss: 6.2413
# Epoch 450/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8027 - loss: 1.1372 - val_accuracy: 0.0816 - val_loss: 6.2433
# Epoch 451/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7751 - loss: 1.1907 - val_accuracy: 0.0816 - val_loss: 6.2456
# Epoch 452/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7980 - loss: 1.1483 - val_accuracy: 0.0816 - val_loss: 6.2478
# Epoch 453/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7769 - loss: 1.2189 - val_accuracy: 0.0816 - val_loss: 6.2502
# Epoch 454/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8131 - loss: 1.1837 - val_accuracy: 0.0816 - val_loss: 6.2529
# Epoch 455/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8457 - loss: 1.1115 - val_accuracy: 0.0816 - val_loss: 6.2564
# Epoch 456/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8286 - loss: 1.1324 - val_accuracy: 0.0816 - val_loss: 6.2583
# Epoch 457/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7880 - loss: 1.2005 - val_accuracy: 0.0816 - val_loss: 6.2610
# Epoch 458/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7627 - loss: 1.1912 - val_accuracy: 0.0816 - val_loss: 6.2632
# Epoch 459/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8173 - loss: 1.1621 - val_accuracy: 0.0816 - val_loss: 6.2641
# Epoch 460/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7981 - loss: 1.1726 - val_accuracy: 0.0816 - val_loss: 6.2656
# Epoch 461/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8061 - loss: 1.1451 - val_accuracy: 0.0816 - val_loss: 6.2676
# Epoch 462/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7969 - loss: 1.1675 - val_accuracy: 0.0816 - val_loss: 6.2700
# Epoch 463/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7983 - loss: 1.1394 - val_accuracy: 0.0816 - val_loss: 6.2726
# Epoch 464/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8136 - loss: 1.1659 - val_accuracy: 0.0816 - val_loss: 6.2756
# Epoch 465/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8029 - loss: 1.1356 - val_accuracy: 0.0816 - val_loss: 6.2782
# Epoch 466/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8182 - loss: 1.1012 - val_accuracy: 0.0816 - val_loss: 6.2809
# Epoch 467/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8010 - loss: 1.1016 - val_accuracy: 0.0816 - val_loss: 6.2837
# Epoch 468/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8257 - loss: 1.0985 - val_accuracy: 0.0816 - val_loss: 6.2860
# Epoch 469/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8220 - loss: 1.0559 - val_accuracy: 0.0816 - val_loss: 6.2884
# Epoch 470/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8158 - loss: 1.1346 - val_accuracy: 0.0816 - val_loss: 6.2909
# Epoch 471/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8307 - loss: 1.1076 - val_accuracy: 0.0816 - val_loss: 6.2934
# Epoch 472/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8101 - loss: 1.1249 - val_accuracy: 0.0816 - val_loss: 6.2961
# Epoch 473/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8087 - loss: 1.1010 - val_accuracy: 0.0816 - val_loss: 6.2986
# Epoch 474/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8398 - loss: 1.0609 - val_accuracy: 0.0816 - val_loss: 6.2996
# Epoch 475/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8148 - loss: 1.0952 - val_accuracy: 0.0816 - val_loss: 6.3013
# Epoch 476/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8175 - loss: 1.1158 - val_accuracy: 0.0816 - val_loss: 6.3035
# Epoch 477/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8061 - loss: 1.0958 - val_accuracy: 0.0816 - val_loss: 6.3066
# Epoch 478/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8111 - loss: 1.1121 - val_accuracy: 0.0816 - val_loss: 6.3097
# Epoch 479/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8256 - loss: 1.0744 - val_accuracy: 0.0816 - val_loss: 6.3128
# Epoch 480/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7999 - loss: 1.0830 - val_accuracy: 0.0816 - val_loss: 6.3154
# Epoch 481/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8236 - loss: 1.0917 - val_accuracy: 0.0816 - val_loss: 6.3173
# Epoch 482/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8224 - loss: 1.0638 - val_accuracy: 0.0816 - val_loss: 6.3200
# Epoch 483/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8024 - loss: 1.1011 - val_accuracy: 0.0816 - val_loss: 6.3227
# Epoch 484/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8510 - loss: 1.0496 - val_accuracy: 0.0816 - val_loss: 6.3255
# Epoch 485/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8069 - loss: 1.0891 - val_accuracy: 0.0816 - val_loss: 6.3284
# Epoch 486/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8232 - loss: 1.0702 - val_accuracy: 0.0816 - val_loss: 6.3317
# Epoch 487/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8436 - loss: 1.0278 - val_accuracy: 0.0816 - val_loss: 6.3349
# Epoch 488/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8348 - loss: 1.0275 - val_accuracy: 0.0816 - val_loss: 6.3376
# Epoch 489/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8109 - loss: 1.0692 - val_accuracy: 0.0816 - val_loss: 6.3403
# Epoch 490/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8348 - loss: 1.0047 - val_accuracy: 0.0816 - val_loss: 6.3428
# Epoch 491/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8441 - loss: 1.0511 - val_accuracy: 0.0816 - val_loss: 6.3459
# Epoch 492/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8659 - loss: 0.9937 - val_accuracy: 0.0816 - val_loss: 6.3489
# Epoch 493/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8366 - loss: 1.0381 - val_accuracy: 0.0816 - val_loss: 6.3528
# Epoch 494/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8425 - loss: 1.0444 - val_accuracy: 0.0816 - val_loss: 6.3557
# Epoch 495/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8247 - loss: 1.0529 - val_accuracy: 0.0816 - val_loss: 6.3581
# Epoch 496/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8709 - loss: 0.9919 - val_accuracy: 0.0816 - val_loss: 6.3610
# Epoch 497/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8386 - loss: 1.0136 - val_accuracy: 0.0816 - val_loss: 6.3632
# Epoch 498/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8178 - loss: 1.0443 - val_accuracy: 0.0816 - val_loss: 6.3654
# Epoch 499/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8235 - loss: 1.0171 - val_accuracy: 0.0816 - val_loss: 6.3679
# Epoch 500/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8291 - loss: 1.0040 - val_accuracy: 0.0816 - val_loss: 6.3704

# %%
model.save('cbow_model.weights.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# # Predicting a Word Using the Trained CBOW Model

# %% [markdown]
# In this step, we define a function to predict a word based on a given context using the trained CBOW model.
#
# 1. **Function: `predict_word`**:
#    - **Input**: The function takes a list of context words as input. The number of context words should match the expected size (2 times the window size).
#    - **Context sequence conversion**: The input context words are tokenized into a sequence of integers using the same tokenizer that was used during training.
#    - **Input validation**: The function checks whether the length of the context sequence matches the expected size (2 times the window size). If not, it prints an error message.
#    - **Prediction**: The tokenized context is fed into the trained CBOW model, which predicts the probability distribution over the vocabulary.
#    - **Retrieve predicted word**: The predicted word is the one with the highest probability. The function retrieves the word corresponding to the predicted index from the tokenizer's word index.
#
# 2. **Example**:
#    - We provide a sample context: `['الحادث', 'بسبب', 'مزدحم', 'الطريق']`.
#    - The function predicts the word that fits best in this context, based on the model's learned weights.
#    - The predicted word is printed along with the input context.
#
# This function allows us to test the CBOW model by predicting words based on their surrounding context from the corpus.

# %% [markdown]
# ## ^ Same as above

# %%
def predict_word(context_words):
    context_sequence = tokenizer.texts_to_sequences([context_words])[0]
    prediction = model.predict(np.array([context_sequence]))
    predicted_index = np.argmax(prediction)
    predicted_word = tokenizer.index_word[predicted_index]
    return predicted_word

context = ["الطريق", 'مزدحم', 'بسبب', 'الحادث']
predicted_word = predict_word(context)
print(f"Context: {context}")
print(f"Predicted word: {predicted_word}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Context: ['الطريق', 'مزدحم', 'بسبب', 'الحادث']
# Predicted word: اليوم

# %% [markdown]
# * https://www.tensorflow.org/api_docs/python/tf/keras/layers/Lambda
# * https://www.tensorflow.org/api_docs/python/tf/compat/v1/reduce_mean
