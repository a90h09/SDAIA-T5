# %% [markdown]
# # Road Traffic Vehicle Counting Exam

# %% [markdown]
# In this exam, you will use the YOLO (You Only Look Once) object detection model to analyze a video of road traffic. Your primary task is to count the number of vehicles exiting the road at each of the four exits (located at the top, bottom, left, and right of the frame). The video for this task is provided at `Datasets/YOLO_Exam_Video.mp4`.
#
# ## Objectives
# - Load and process the video using OpenCV.
# - Utilize the YOLO model to detect vehicles in each frame.
# - Manipulate the video frames using OpenCV.
# - Track vehicles as they move across the video frames.
# - Count the number of vehicles exiting via the top street.
# - Count the number of vehicles exiting via the bottom street.
# - Count the number of vehicles exiting via the left street.
# - Count the number of vehicles exiting via the right street.

# %% [markdown]
# ## Setup Environment

# %% [markdown]
# Before you begin, ensure you have the necessary libraries installed. You will need `opencv`, and `ultralytics` among others.
# If these are not installed, you should install them.

# %%
# !pip install ultralytics
# !pip install opencv-python

# %%
from ultralytics import YOLO , solutions
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %% [markdown]
# ## Load the YOLO Model

# %% [markdown]
# You will first need to load the YOLO model, there is a custom model for this exam called `YOLO_Model.pt` under Datasets file ⚠️ PLEASE USE THIS MODEL AND DO NOT USE ANY OTHER MODEL ⚠️.
# Write the code to load the YOLO model below:

# %%
model = YOLO('/content/YOLO_Model.pt')

# %% [markdown]
# ## Prepare the Video Capture

# %% [markdown]
# Create a variable to capture the video frames, you can use `cv2.VideoCapture()` to achive this.

# %%
# Prepare the video capture
video_path = '/content/YOLO_Video.mp4'
cap = cv2.VideoCapture(video_path)

# %% [markdown]
# ## Get Video Information

# %% [markdown]
# You can use `cv2` library to get these information fro the `VideoCapture()` variable you created to extract these information:
# * `height`: Video's height.
# * `width`: Video's width.
# * `fps`: Video's frames.

# %%
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# %%
print("Height:", height)
print("Width:", width)
print("FPS:", fps)
# Out:
# Height: 1080
# Width: 1920
# FPS: 29

# %% [markdown]
# ## Prepare Video Writer to Store the Output

# %% [markdown]
# Create a variable that uses `cv2.VideoCapture()` to save the video with the bounding boxes, specified Region of Interest rectangle (ROI) and the counted vehicles on each sides. You will need to make the video with the same `fps`, `width`, `height`, and specify the codec and output path of the video.

# %%
output_path = 'output_video.avi'
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

# %% [markdown]
# ## Expermint to get the `(x1, y1, x2, y2)` of the ROI

# %% [markdown]
# ### Hint
# When defining the Regions of Interest (ROIs) for detecting vehicles exiting the road, consider the coordinates that outline the relevant areas. These coordinates can be specified as `(x1, y1, x2, y2)`, where `(x1, y1)` is the top-left corner and `(x2, y2)` is the bottom-right corner of the rectangle.
#
# Experiment with different coordinates to accurately cover the streets where vehicles exit. Visualize these ROIs by drawing rectangles on a frame of the video and adjust the coordinates as needed until you capture the desired areas effectively.

# %%
# Regions
top_exit = (1000, 50, 1300, 200)
bottom_exit = (600, 900, 900, 1000)
left_exit = (400, 300, 600, 550)
right_exit = (1250, 450, 1450, 750)

# %%
# cars count
top_count = 0
bottom_count = 0
left_count = 0
right_count = 0

# %%
# Saves cars ID on sets
top_exited_ids = set()
bottom_exited_ids = set()
left_exited_ids = set()
right_exited_ids = set()

# %% [markdown]
# ## Process Video Frames and Identify Vehicles Left the Road Form Each Street

# %% [markdown]
# For each frame in the video, use the YOLO model to detect and track vehicles. You will need to write a loop that processes each frame and applies the YOLO model.
#
# In each frame, after detecting the vehicles, determine whether they exited the road via the top, bottom, left, or right street. You can use the positions of the bounding boxes provided by YOLO to do this.
#
# - The video should display bounding boxes around the detected objects.
# - The video should display your name on the top.
# - It should display the calculated center of each vehicle.
# - The video should display the confidence score, alongside the object ID and class ID of each detected and tracked object.
# - The video should display the rectangles representing the regions where you count the vehicles that have crossed and exited.
# - The video should display the number of vehicles that exited via the top street.
# - The video should display the number of vehicles that exited via the bottom street.
# - The video should display the number of vehicles that exited via the left street.
# - The video should display the number of vehicles that exited via the right street.

# %% [markdown]
# #Doesn't work!

# %%
# region_points = [(1000,1300),(900, 600),(400,600),(1450, 1250)]

# %%
# video_writer = cv2.VideoWriter(output_path, cv2.VideoWriter_fourcc(*"mp4v"), fps, (width, height))

# %%
# counter = solutions.ObjectCounter(
#     view_img=True,
#     reg_pts=region_points,
#     names=model.names,
#     draw_tracks=True,
#     line_thickness=2,
# )

# %%
# while cap.isOpened():
#         success, im0 = cap.read()
#         if not success:
#             print("Video frame is empty or video processing has been successfully completed.")
#             break
#         tracks = model.track(im0, persist=True, show=False)
#         im0 = counter.start_counting(im0, tracks)
#         video_writer.write(im0)
#         cv2_imshow(im0)

# %% [markdown]
# #Trying Diffrent solution

# %%
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLO model on the frame
    results = model.track(frame, persist=True)

    for result in results:
        for boxes in result.boxes:

            # Get Object details
            bbox = boxes.xyxy[0].cpu().numpy()          #Bounding Box
            class_id = int(boxes.cls[0].cpu().numpy())  #Class ID
            conf = boxes.conf[0].cpu().numpy()          #Confidence
            id = int(boxes.id[0].cpu().numpy())         #Object ID

            x1, y1, x2, y2 = map(int, bbox)
            # Get the center of the Object
            center_x, center_y = (x1 + x2) // 2, (y1 + y2) // 2

            # Draw BBox
            cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 0, 0), 2)

            label = f'ID: {id} Conf: {conf:.2f} Class:{class_id}'
            # Add labels for each car
            cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 1, cv2.LINE_AA)

            # Count vehicles based on their exit region
            # Top Reigon
            if top_exit[0] < center_x < top_exit[2] and top_exit[1] < center_y < top_exit[3]:
                if id not in top_exited_ids: # if the id is not in the set +1
                    top_count += 1
                    top_exited_ids.add(id) # add id to the set
            # Bottom Reigon
            elif bottom_exit[0] < center_x < bottom_exit[2] and bottom_exit[1] < center_y < bottom_exit[3]:
                if id not in bottom_exited_ids: # if the id is not in the set +1
                    bottom_count += 1
                    bottom_exited_ids.add(id) # add id to the set
            # Left Reigon
            elif left_exit[0] < center_x < left_exit[2] and left_exit[1] < center_y < left_exit[3]:
                if id not in left_exited_ids: # if the id is not in the set +1
                    left_count += 1
                    left_exited_ids.add(id) # add id to the set
            # Right Reigon
            elif right_exit[0] < center_x < right_exit[2] and right_exit[1] < center_y < right_exit[3]:
                if id not in right_exited_ids: # if the id is not in the set +1
                    right_count += 1
                    right_exited_ids.add(id) # add id to the set




    # Display the counts on the video frame
    cv2.putText(frame, f'Top Exit: {top_count}', (25, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)
    cv2.putText(frame, f'Bottom Exit: {bottom_count}', (25, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)
    cv2.putText(frame, f'Left Exit: {left_count}', (25, 90), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)
    cv2.putText(frame, f'Right Exit: {right_count}', (25, 120), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)

    # Display my name
    cv2.putText(frame, 'Ahmed Bashmmakh', (300, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    # Creating Reigons in the frames
    #Top
    cv2.rectangle(frame, top_exit[:2], top_exit[2:], (0, 0, 255), 2)
    #Bottom
    cv2.rectangle(frame, bottom_exit[:2], bottom_exit[2:], (0, 0, 255), 2)
    #Left
    cv2.rectangle(frame, left_exit[:2], left_exit[2:], (0, 0, 255), 2)
    #Right
    cv2.rectangle(frame, right_exit[:2], right_exit[2:], (0, 0, 255), 2)

    out.write(frame)

    # Display each frame
    # cv2_imshow(frame)
# Out:
# 0: 384x640 11 cars, 2389.7ms
# Speed: 3.8ms preprocess, 2389.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2389.5ms
# Speed: 4.3ms preprocess, 2389.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2406.0ms
# Speed: 4.5ms preprocess, 2406.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 2501.1ms
# Speed: 3.1ms preprocess, 2501.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 3634.7ms
# Speed: 3.7ms preprocess, 3634.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2418.8ms
# Speed: 4.7ms preprocess, 2418.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2431.2ms
# Speed: 3.8ms preprocess, 2431.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2393.7ms
# Speed: 3.8ms preprocess, 2393.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2683.0ms
# Speed: 4.3ms preprocess, 2683.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 3373.7ms
# Speed: 4.1ms preprocess, 3373.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2393.0ms
# Speed: 3.7ms preprocess, 2393.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2432.7ms
# Speed: 4.2ms preprocess, 2432.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2467.8ms
# Speed: 4.8ms preprocess, 2467.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2978.7ms
# Speed: 4.3ms preprocess, 2978.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3035.5ms
# Speed: 4.2ms preprocess, 3035.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2404.1ms
# Speed: 4.0ms preprocess, 2404.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2459.2ms
# Speed: 6.1ms preprocess, 2459.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2429.1ms
# Speed: 3.3ms preprocess, 2429.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 truck, 3449.4ms
# Speed: 3.8ms preprocess, 3449.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2587.3ms
# Speed: 4.7ms preprocess, 2587.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2387.0ms
# Speed: 4.1ms preprocess, 2387.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2391.8ms
# Speed: 3.8ms preprocess, 2391.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2449.9ms
# Speed: 3.8ms preprocess, 2449.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 3665.7ms
# Speed: 4.8ms preprocess, 3665.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2399.2ms
# Speed: 4.0ms preprocess, 2399.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 15 cars, 2406.8ms
# Speed: 4.1ms preprocess, 2406.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2389.2ms
# Speed: 3.8ms preprocess, 2389.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2462.8ms
# Speed: 6.1ms preprocess, 2462.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 3558.8ms
# Speed: 4.1ms preprocess, 3558.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2432.8ms
# Speed: 2.7ms preprocess, 2432.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2428.3ms
# Speed: 4.2ms preprocess, 2428.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2389.9ms
# Speed: 3.8ms preprocess, 2389.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2746.5ms
# Speed: 4.4ms preprocess, 2746.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 3283.7ms
# Speed: 5.4ms preprocess, 3283.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2412.7ms
# Speed: 4.1ms preprocess, 2412.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2415.6ms
# Speed: 4.1ms preprocess, 2415.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2442.9ms
# Speed: 4.1ms preprocess, 2442.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 3142.0ms
# Speed: 4.0ms preprocess, 3142.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2981.2ms
# Speed: 4.0ms preprocess, 2981.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2422.4ms
# Speed: 4.1ms preprocess, 2422.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 13 cars, 2449.9ms
# Speed: 4.3ms preprocess, 2449.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2460.2ms
# Speed: 3.7ms preprocess, 2460.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 3645.7ms
# Speed: 4.3ms preprocess, 3645.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2465.6ms
# Speed: 4.1ms preprocess, 2465.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2463.5ms
# Speed: 3.7ms preprocess, 2463.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2442.9ms
# Speed: 5.4ms preprocess, 2442.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2469.8ms
# Speed: 4.0ms preprocess, 2469.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 14 cars, 3597.8ms
# Speed: 4.2ms preprocess, 3597.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2490.4ms
# Speed: 3.8ms preprocess, 2490.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2422.8ms
# Speed: 3.2ms preprocess, 2422.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2487.7ms
# Speed: 2.8ms preprocess, 2487.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2846.3ms
# Speed: 3.8ms preprocess, 2846.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 3197.9ms
# Speed: 4.0ms preprocess, 3197.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2409.9ms
# Speed: 4.9ms preprocess, 2409.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2489.6ms
# Speed: 3.8ms preprocess, 2489.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2411.6ms
# Speed: 6.1ms preprocess, 2411.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3288.2ms
# Speed: 4.8ms preprocess, 3288.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2781.2ms
# Speed: 4.0ms preprocess, 2781.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2467.8ms
# Speed: 3.9ms preprocess, 2467.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2436.6ms
# Speed: 3.8ms preprocess, 2436.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2441.6ms
# Speed: 3.8ms preprocess, 2441.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3697.6ms
# Speed: 3.8ms preprocess, 3697.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2445.2ms
# Speed: 3.9ms preprocess, 2445.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2472.8ms
# Speed: 4.1ms preprocess, 2472.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2399.9ms
# Speed: 3.9ms preprocess, 2399.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2468.8ms
# Speed: 4.1ms preprocess, 2468.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 truck, 3585.4ms
# Speed: 4.4ms preprocess, 3585.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2421.7ms
# Speed: 5.5ms preprocess, 2421.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 1 truck, 2435.6ms
# Speed: 4.0ms preprocess, 2435.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 1 truck, 2433.1ms
# Speed: 3.8ms preprocess, 2433.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2820.3ms
# Speed: 3.8ms preprocess, 2820.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3218.1ms
# Speed: 7.2ms preprocess, 3218.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2428.8ms
# Speed: 3.3ms preprocess, 2428.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2412.9ms
# Speed: 3.8ms preprocess, 2412.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2411.5ms
# Speed: 4.1ms preprocess, 2411.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3232.6ms
# Speed: 3.9ms preprocess, 3232.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2840.3ms
# Speed: 4.3ms preprocess, 2840.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2403.6ms
# Speed: 4.0ms preprocess, 2403.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2443.4ms
# Speed: 3.8ms preprocess, 2443.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2420.6ms
# Speed: 3.9ms preprocess, 2420.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3646.7ms
# Speed: 4.0ms preprocess, 3646.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2435.9ms
# Speed: 4.6ms preprocess, 2435.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2504.6ms
# Speed: 3.9ms preprocess, 2504.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2445.0ms
# Speed: 4.7ms preprocess, 2445.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2593.3ms
# Speed: 3.8ms preprocess, 2593.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3502.8ms
# Speed: 4.4ms preprocess, 3502.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2467.3ms
# Speed: 4.0ms preprocess, 2467.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2405.9ms
# Speed: 4.9ms preprocess, 2405.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2450.0ms
# Speed: 4.0ms preprocess, 2450.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3028.8ms
# Speed: 6.6ms preprocess, 3028.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3051.7ms
# Speed: 6.2ms preprocess, 3051.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2453.4ms
# Speed: 4.0ms preprocess, 2453.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2487.6ms
# Speed: 5.7ms preprocess, 2487.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2441.2ms
# Speed: 3.5ms preprocess, 2441.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3487.1ms
# Speed: 4.0ms preprocess, 3487.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2631.5ms
# Speed: 8.2ms preprocess, 2631.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2414.6ms
# Speed: 4.1ms preprocess, 2414.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2430.8ms
# Speed: 3.8ms preprocess, 2430.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2492.0ms
# Speed: 4.0ms preprocess, 2492.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3653.0ms
# Speed: 6.2ms preprocess, 3653.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2432.3ms
# Speed: 3.8ms preprocess, 2432.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2492.7ms
# Speed: 4.6ms preprocess, 2492.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2401.1ms
# Speed: 3.8ms preprocess, 2401.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2735.8ms
# Speed: 4.0ms preprocess, 2735.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3434.4ms
# Speed: 4.3ms preprocess, 3434.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2434.2ms
# Speed: 4.2ms preprocess, 2434.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2458.1ms
# Speed: 3.9ms preprocess, 2458.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2420.7ms
# Speed: 4.0ms preprocess, 2420.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 3152.5ms
# Speed: 3.9ms preprocess, 3152.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2926.5ms
# Speed: 6.7ms preprocess, 2926.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2458.2ms
# Speed: 5.0ms preprocess, 2458.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2492.0ms
# Speed: 3.2ms preprocess, 2492.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2413.4ms
# Speed: 5.9ms preprocess, 2413.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 3600.4ms
# Speed: 3.1ms preprocess, 3600.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2536.0ms
# Speed: 4.0ms preprocess, 2536.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2505.4ms
# Speed: 4.2ms preprocess, 2505.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2415.7ms
# Speed: 4.2ms preprocess, 2415.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2425.7ms
# Speed: 4.4ms preprocess, 2425.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3664.7ms
# Speed: 4.0ms preprocess, 3664.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2423.0ms
# Speed: 4.0ms preprocess, 2423.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2488.3ms
# Speed: 3.8ms preprocess, 2488.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2450.1ms
# Speed: 4.1ms preprocess, 2450.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2827.4ms
# Speed: 5.6ms preprocess, 2827.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3236.1ms
# Speed: 5.0ms preprocess, 3236.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2419.6ms
# Speed: 5.8ms preprocess, 2419.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2491.6ms
# Speed: 4.8ms preprocess, 2491.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2426.5ms
# Speed: 4.1ms preprocess, 2426.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3219.9ms
# Speed: 3.8ms preprocess, 3219.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2889.7ms
# Speed: 13.0ms preprocess, 2889.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2422.3ms
# Speed: 3.9ms preprocess, 2422.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2424.8ms
# Speed: 4.8ms preprocess, 2424.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2411.7ms
# Speed: 4.8ms preprocess, 2411.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3757.4ms
# Speed: 4.2ms preprocess, 3757.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2415.3ms
# Speed: 4.8ms preprocess, 2415.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2466.2ms
# Speed: 3.8ms preprocess, 2466.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2406.4ms
# Speed: 4.6ms preprocess, 2406.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2498.2ms
# Speed: 3.9ms preprocess, 2498.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3630.2ms
# Speed: 4.0ms preprocess, 3630.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2434.0ms
# Speed: 3.9ms preprocess, 2434.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2447.8ms
# Speed: 3.8ms preprocess, 2447.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2432.7ms
# Speed: 3.8ms preprocess, 2432.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2931.9ms
# Speed: 4.0ms preprocess, 2931.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3208.7ms
# Speed: 4.1ms preprocess, 3208.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2423.2ms
# Speed: 4.0ms preprocess, 2423.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2502.6ms
# Speed: 4.1ms preprocess, 2502.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2394.0ms
# Speed: 3.9ms preprocess, 2394.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3206.8ms
# Speed: 4.7ms preprocess, 3206.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 van, 2943.3ms
# Speed: 5.8ms preprocess, 2943.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2425.6ms
# Speed: 6.5ms preprocess, 2425.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2425.4ms
# Speed: 4.2ms preprocess, 2425.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2459.5ms
# Speed: 3.9ms preprocess, 2459.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3682.1ms
# Speed: 2.9ms preprocess, 3682.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2441.3ms
# Speed: 4.3ms preprocess, 2441.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2477.8ms
# Speed: 4.3ms preprocess, 2477.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2420.5ms
# Speed: 3.8ms preprocess, 2420.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2444.0ms
# Speed: 3.9ms preprocess, 2444.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3587.5ms
# Speed: 3.8ms preprocess, 3587.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2437.4ms
# Speed: 3.0ms preprocess, 2437.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2475.4ms
# Speed: 4.0ms preprocess, 2475.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2468.5ms
# Speed: 4.1ms preprocess, 2468.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2925.9ms
# Speed: 5.9ms preprocess, 2925.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3205.5ms
# Speed: 5.3ms preprocess, 3205.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2461.5ms
# Speed: 4.4ms preprocess, 2461.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2472.0ms
# Speed: 3.4ms preprocess, 2472.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2433.8ms
# Speed: 4.2ms preprocess, 2433.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3246.8ms
# Speed: 4.5ms preprocess, 3246.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2835.3ms
# Speed: 7.3ms preprocess, 2835.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2497.2ms
# Speed: 3.9ms preprocess, 2497.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2420.5ms
# Speed: 4.2ms preprocess, 2420.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2518.0ms
# Speed: 4.2ms preprocess, 2518.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3680.7ms
# Speed: 4.7ms preprocess, 3680.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2514.0ms
# Speed: 4.0ms preprocess, 2514.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2449.0ms
# Speed: 4.0ms preprocess, 2449.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2425.0ms
# Speed: 3.9ms preprocess, 2425.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2642.4ms
# Speed: 4.1ms preprocess, 2642.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3496.0ms
# Speed: 4.0ms preprocess, 3496.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2458.9ms
# Speed: 4.8ms preprocess, 2458.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2419.7ms
# Speed: 3.5ms preprocess, 2419.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2423.7ms
# Speed: 4.1ms preprocess, 2423.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2945.1ms
# Speed: 3.7ms preprocess, 2945.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3174.0ms
# Speed: 4.2ms preprocess, 3174.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2464.0ms
# Speed: 3.9ms preprocess, 2464.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 6 cars, 2496.3ms
# Speed: 3.3ms preprocess, 2496.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2456.4ms
# Speed: 4.3ms preprocess, 2456.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3349.7ms
# Speed: 4.1ms preprocess, 3349.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 7 cars, 2750.7ms
# Speed: 5.3ms preprocess, 2750.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2473.7ms
# Speed: 4.1ms preprocess, 2473.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2462.5ms
# Speed: 4.4ms preprocess, 2462.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2444.4ms
# Speed: 5.5ms preprocess, 2444.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3783.8ms
# Speed: 4.2ms preprocess, 3783.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2443.5ms
# Speed: 4.3ms preprocess, 2443.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2480.6ms
# Speed: 4.6ms preprocess, 2480.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2420.0ms
# Speed: 4.1ms preprocess, 2420.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2618.1ms
# Speed: 4.1ms preprocess, 2618.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3384.3ms
# Speed: 4.9ms preprocess, 3384.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2486.0ms
# Speed: 4.4ms preprocess, 2486.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2434.1ms
# Speed: 4.1ms preprocess, 2434.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2432.9ms
# Speed: 4.0ms preprocess, 2432.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3052.0ms
# Speed: 4.7ms preprocess, 3052.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3004.2ms
# Speed: 4.9ms preprocess, 3004.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2446.7ms
# Speed: 3.9ms preprocess, 2446.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2513.0ms
# Speed: 4.2ms preprocess, 2513.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2428.1ms
# Speed: 3.9ms preprocess, 2428.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3493.1ms
# Speed: 4.0ms preprocess, 3493.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2585.9ms
# Speed: 6.7ms preprocess, 2585.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2486.2ms
# Speed: 5.3ms preprocess, 2486.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2432.2ms
# Speed: 3.9ms preprocess, 2432.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2483.2ms
# Speed: 3.9ms preprocess, 2483.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3716.9ms
# Speed: 4.1ms preprocess, 3716.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2419.2ms
# Speed: 3.9ms preprocess, 2419.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2453.0ms
# Speed: 4.6ms preprocess, 2453.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2505.7ms
# Speed: 3.8ms preprocess, 2505.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2762.1ms
# Speed: 3.9ms preprocess, 2762.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3378.5ms
# Speed: 4.2ms preprocess, 3378.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2513.0ms
# Speed: 3.9ms preprocess, 2513.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2424.3ms
# Speed: 4.5ms preprocess, 2424.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2459.4ms
# Speed: 4.1ms preprocess, 2459.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 3185.2ms
# Speed: 3.1ms preprocess, 3185.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2977.0ms
# Speed: 4.1ms preprocess, 2977.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2464.3ms
# Speed: 3.9ms preprocess, 2464.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 2438.7ms
# Speed: 4.0ms preprocess, 2438.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2486.7ms
# Speed: 5.5ms preprocess, 2486.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3577.8ms
# Speed: 3.8ms preprocess, 3577.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2632.5ms
# Speed: 4.4ms preprocess, 2632.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2406.2ms
# Speed: 3.9ms preprocess, 2406.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2425.7ms
# Speed: 5.7ms preprocess, 2425.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2504.2ms
# Speed: 4.2ms preprocess, 2504.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 3666.8ms
# Speed: 4.0ms preprocess, 3666.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2479.7ms
# Speed: 2.9ms preprocess, 2479.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2504.3ms
# Speed: 3.7ms preprocess, 2504.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2426.9ms
# Speed: 4.5ms preprocess, 2426.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2704.6ms
# Speed: 4.1ms preprocess, 2704.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3364.3ms
# Speed: 4.1ms preprocess, 3364.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2532.1ms
# Speed: 3.9ms preprocess, 2532.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2462.7ms
# Speed: 4.0ms preprocess, 2462.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2412.0ms
# Speed: 4.1ms preprocess, 2412.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3098.7ms
# Speed: 4.0ms preprocess, 3098.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2946.4ms
# Speed: 4.0ms preprocess, 2946.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 2497.0ms
# Speed: 3.4ms preprocess, 2497.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2415.6ms
# Speed: 3.9ms preprocess, 2415.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2433.8ms
# Speed: 3.9ms preprocess, 2433.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 3596.1ms
# Speed: 4.1ms preprocess, 3596.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2519.5ms
# Speed: 5.0ms preprocess, 2519.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2437.4ms
# Speed: 4.7ms preprocess, 2437.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2526.7ms
# Speed: 7.0ms preprocess, 2526.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2430.3ms
# Speed: 4.0ms preprocess, 2430.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3692.3ms
# Speed: 4.1ms preprocess, 3692.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2469.9ms
# Speed: 3.7ms preprocess, 2469.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2432.3ms
# Speed: 3.9ms preprocess, 2432.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2424.6ms
# Speed: 4.1ms preprocess, 2424.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2789.1ms
# Speed: 4.0ms preprocess, 2789.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 3418.2ms
# Speed: 4.5ms preprocess, 3418.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2458.2ms
# Speed: 4.5ms preprocess, 2458.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2439.6ms
# Speed: 4.4ms preprocess, 2439.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2488.7ms
# Speed: 3.4ms preprocess, 2488.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 3127.3ms
# Speed: 4.3ms preprocess, 3127.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3014.5ms
# Speed: 6.1ms preprocess, 3014.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2483.5ms
# Speed: 4.0ms preprocess, 2483.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2444.0ms
# Speed: 4.1ms preprocess, 2444.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2439.6ms
# Speed: 4.2ms preprocess, 2439.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3560.9ms
# Speed: 4.4ms preprocess, 3560.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2590.3ms
# Speed: 5.3ms preprocess, 2590.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2428.5ms
# Speed: 4.0ms preprocess, 2428.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2450.7ms
# Speed: 3.8ms preprocess, 2450.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2457.5ms
# Speed: 4.0ms preprocess, 2457.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3717.9ms
# Speed: 3.1ms preprocess, 3717.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 2425.8ms
# Speed: 4.4ms preprocess, 2425.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2451.5ms
# Speed: 4.2ms preprocess, 2451.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2407.6ms
# Speed: 5.4ms preprocess, 2407.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2625.7ms
# Speed: 3.9ms preprocess, 2625.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3519.7ms
# Speed: 4.5ms preprocess, 3519.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2489.5ms
# Speed: 4.1ms preprocess, 2489.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2419.4ms
# Speed: 3.9ms preprocess, 2419.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2451.8ms
# Speed: 4.4ms preprocess, 2451.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3022.9ms
# Speed: 4.1ms preprocess, 3022.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3130.1ms
# Speed: 6.9ms preprocess, 3130.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2469.7ms
# Speed: 4.0ms preprocess, 2469.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2469.0ms
# Speed: 6.1ms preprocess, 2469.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2506.1ms
# Speed: 4.0ms preprocess, 2506.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3514.5ms
# Speed: 4.8ms preprocess, 3514.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2596.8ms
# Speed: 5.0ms preprocess, 2596.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2446.3ms
# Speed: 4.0ms preprocess, 2446.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2442.4ms
# Speed: 4.0ms preprocess, 2442.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2440.2ms
# Speed: 4.0ms preprocess, 2440.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3667.8ms
# Speed: 4.0ms preprocess, 3667.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2484.6ms
# Speed: 4.1ms preprocess, 2484.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2461.0ms
# Speed: 3.8ms preprocess, 2461.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2466.8ms
# Speed: 5.4ms preprocess, 2466.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2807.6ms
# Speed: 4.1ms preprocess, 2807.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 3320.3ms
# Speed: 4.1ms preprocess, 3320.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2434.8ms
# Speed: 4.3ms preprocess, 2434.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2432.7ms
# Speed: 4.6ms preprocess, 2432.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2502.1ms
# Speed: 4.2ms preprocess, 2502.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3157.0ms
# Speed: 3.4ms preprocess, 3157.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2925.9ms
# Speed: 4.2ms preprocess, 2925.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2423.0ms
# Speed: 2.8ms preprocess, 2423.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2453.8ms
# Speed: 4.0ms preprocess, 2453.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2442.4ms
# Speed: 4.2ms preprocess, 2442.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 3730.2ms
# Speed: 3.2ms preprocess, 3730.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2468.9ms
# Speed: 4.4ms preprocess, 2468.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2462.4ms
# Speed: 4.0ms preprocess, 2462.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2427.8ms
# Speed: 4.1ms preprocess, 2427.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2421.0ms
# Speed: 3.9ms preprocess, 2421.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3685.2ms
# Speed: 4.0ms preprocess, 3685.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2445.7ms
# Speed: 4.0ms preprocess, 2445.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2486.8ms
# Speed: 4.0ms preprocess, 2486.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2423.0ms
# Speed: 3.9ms preprocess, 2423.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2765.2ms
# Speed: 3.8ms preprocess, 2765.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 3367.3ms
# Speed: 6.6ms preprocess, 3367.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2460.4ms
# Speed: 5.2ms preprocess, 2460.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2464.4ms
# Speed: 3.2ms preprocess, 2464.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2422.7ms
# Speed: 3.8ms preprocess, 2422.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3149.8ms
# Speed: 4.1ms preprocess, 3149.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2892.3ms
# Speed: 4.5ms preprocess, 2892.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2485.6ms
# Speed: 4.9ms preprocess, 2485.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2447.7ms
# Speed: 3.9ms preprocess, 2447.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2419.5ms
# Speed: 4.0ms preprocess, 2419.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3616.1ms
# Speed: 3.9ms preprocess, 3616.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2462.7ms
# Speed: 4.1ms preprocess, 2462.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2467.9ms
# Speed: 4.1ms preprocess, 2467.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2481.1ms
# Speed: 4.2ms preprocess, 2481.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2434.2ms
# Speed: 4.1ms preprocess, 2434.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3597.0ms
# Speed: 3.7ms preprocess, 3597.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2459.3ms
# Speed: 4.0ms preprocess, 2459.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2421.4ms
# Speed: 3.9ms preprocess, 2421.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2425.3ms
# Speed: 3.9ms preprocess, 2425.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2875.2ms
# Speed: 3.9ms preprocess, 2875.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3251.4ms
# Speed: 7.0ms preprocess, 3251.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2424.9ms
# Speed: 4.0ms preprocess, 2424.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2444.0ms
# Speed: 3.8ms preprocess, 2444.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2457.5ms
# Speed: 3.8ms preprocess, 2457.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3152.8ms
# Speed: 3.9ms preprocess, 3152.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2947.8ms
# Speed: 5.4ms preprocess, 2947.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2422.9ms
# Speed: 4.0ms preprocess, 2422.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2440.4ms
# Speed: 5.6ms preprocess, 2440.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2471.7ms
# Speed: 6.4ms preprocess, 2471.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 3602.5ms
# Speed: 4.1ms preprocess, 3602.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2500.2ms
# Speed: 4.0ms preprocess, 2500.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2449.6ms
# Speed: 4.6ms preprocess, 2449.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2441.1ms
# Speed: 3.8ms preprocess, 2441.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 2458.0ms
# Speed: 3.8ms preprocess, 2458.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 3740.0ms
# Speed: 4.0ms preprocess, 3740.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2450.0ms
# Speed: 5.8ms preprocess, 2450.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 2459.7ms
# Speed: 3.9ms preprocess, 2459.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2420.3ms
# Speed: 4.0ms preprocess, 2420.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2704.9ms
# Speed: 4.0ms preprocess, 2704.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 13 cars, 3404.9ms
# Speed: 5.2ms preprocess, 3404.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 14 cars, 2435.3ms
# Speed: 3.9ms preprocess, 2435.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 15 cars, 2446.1ms
# Speed: 2.8ms preprocess, 2446.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 15 cars, 2470.2ms
# Speed: 4.0ms preprocess, 2470.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 15 cars, 3053.0ms
# Speed: 4.6ms preprocess, 3053.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 15 cars, 3064.2ms
# Speed: 4.1ms preprocess, 3064.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 15 cars, 2467.0ms
# Speed: 4.7ms preprocess, 2467.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 15 cars, 2449.0ms
# Speed: 4.3ms preprocess, 2449.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 2435.9ms
# Speed: 4.0ms preprocess, 2435.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 3557.5ms
# Speed: 4.0ms preprocess, 3557.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 2610.4ms
# Speed: 4.1ms preprocess, 2610.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 2499.7ms
# Speed: 4.3ms preprocess, 2499.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 2450.2ms
# Speed: 4.4ms preprocess, 2450.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 2430.0ms
# Speed: 3.9ms preprocess, 2430.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 15 cars, 3685.4ms
# Speed: 4.0ms preprocess, 3685.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 15 cars, 2441.6ms
# Speed: 3.9ms preprocess, 2441.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 15 cars, 2495.7ms
# Speed: 3.9ms preprocess, 2495.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 15 cars, 2410.4ms
# Speed: 3.9ms preprocess, 2410.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 15 cars, 2795.5ms
# Speed: 3.3ms preprocess, 2795.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 15 cars, 3287.5ms
# Speed: 3.8ms preprocess, 3287.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 2446.0ms
# Speed: 3.9ms preprocess, 2446.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 2408.0ms
# Speed: 4.0ms preprocess, 2408.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 17 cars, 2453.5ms
# Speed: 5.2ms preprocess, 2453.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 17 cars, 3098.1ms
# Speed: 4.0ms preprocess, 3098.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 2936.4ms
# ...
#
# 0: 384x640 1 bus, 21 cars, 2439.9ms
# Speed: 4.1ms preprocess, 2439.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 22 cars, 2430.1ms
# Speed: 4.1ms preprocess, 2430.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 24 cars, 3620.4ms
# Speed: 4.1ms preprocess, 3620.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 23 cars, 2507.8ms
# Speed: 4.5ms preprocess, 2507.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 23 cars, 2426.9ms
# Speed: 3.9ms preprocess, 2426.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 22 cars, 2426.8ms
# Speed: 3.9ms preprocess, 2426.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 23 cars, 2430.9ms
# Speed: 4.0ms preprocess, 2430.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 24 cars, 3694.1ms
# Speed: 4.1ms preprocess, 3694.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 22 cars, 2443.4ms
# Speed: 4.1ms preprocess, 2443.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 22 cars, 2410.5ms
# Speed: 4.1ms preprocess, 2410.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 23 cars, 2431.5ms
# Speed: 4.8ms preprocess, 2431.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 23 cars, 2702.1ms
# Speed: 6.8ms preprocess, 2702.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 21 cars, 3420.8ms
# Speed: 6.1ms preprocess, 3420.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 21 cars, 2455.8ms
# Speed: 3.8ms preprocess, 2455.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 21 cars, 2454.8ms
# Speed: 5.1ms preprocess, 2454.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 19 cars, 2425.4ms
# Speed: 4.0ms preprocess, 2425.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 19 cars, 3027.1ms
# Speed: 4.1ms preprocess, 3027.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 18 cars, 3024.2ms
# Speed: 7.8ms preprocess, 3024.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 17 cars, 2449.9ms
# Speed: 4.4ms preprocess, 2449.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 18 cars, 2460.3ms
# Speed: 4.2ms preprocess, 2460.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 17 cars, 2447.7ms
# Speed: 4.3ms preprocess, 2447.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 3595.2ms
# Speed: 3.1ms preprocess, 3595.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 2515.5ms
# Speed: 4.4ms preprocess, 2515.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 2458.2ms
# Speed: 7.0ms preprocess, 2458.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 2442.5ms
# Speed: 4.1ms preprocess, 2442.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 2451.9ms
# Speed: 3.2ms preprocess, 2451.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 15 cars, 3689.4ms
# Speed: 4.5ms preprocess, 3689.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 15 cars, 2462.0ms
# Speed: 4.1ms preprocess, 2462.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 2427.7ms
# Speed: 4.1ms preprocess, 2427.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 2445.9ms
# Speed: 4.1ms preprocess, 2445.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 2731.0ms
# Speed: 4.0ms preprocess, 2731.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 3355.2ms
# Speed: 3.9ms preprocess, 3355.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 2439.8ms
# Speed: 3.0ms preprocess, 2439.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 15 cars, 2454.5ms
# Speed: 3.8ms preprocess, 2454.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 15 cars, 2455.4ms
# Speed: 4.2ms preprocess, 2455.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 15 cars, 3137.6ms
# Speed: 4.0ms preprocess, 3137.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 14 cars, 2976.3ms
# Speed: 6.9ms preprocess, 2976.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 14 cars, 2434.7ms
# Speed: 4.1ms preprocess, 2434.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 14 cars, 2411.4ms
# Speed: 4.1ms preprocess, 2411.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 13 cars, 2437.0ms
# Speed: 4.1ms preprocess, 2437.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 14 cars, 3593.3ms
# Speed: 4.1ms preprocess, 3593.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 14 cars, 2432.5ms
# Speed: 4.1ms preprocess, 2432.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 13 cars, 2459.7ms
# Speed: 6.1ms preprocess, 2459.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 13 cars, 2409.7ms
# Speed: 3.3ms preprocess, 2409.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 14 cars, 2419.9ms
# Speed: 4.2ms preprocess, 2419.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 15 cars, 3670.4ms
# Speed: 4.0ms preprocess, 3670.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 2478.5ms
# Speed: 4.1ms preprocess, 2478.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 2414.7ms
# Speed: 4.4ms preprocess, 2414.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 2468.6ms
# Speed: 3.9ms preprocess, 2468.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 17 cars, 2807.4ms
# Speed: 3.9ms preprocess, 2807.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 3296.0ms
# Speed: 4.0ms preprocess, 3296.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 15 cars, 2451.2ms
# Speed: 4.1ms preprocess, 2451.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 2419.9ms
# Speed: 2.8ms preprocess, 2419.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 2420.1ms
# Speed: 4.6ms preprocess, 2420.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 3053.6ms
# Speed: 4.3ms preprocess, 3053.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 3004.0ms
# Speed: 4.0ms preprocess, 3004.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 14 cars, 2425.7ms
# Speed: 3.4ms preprocess, 2425.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 14 cars, 2439.4ms
# Speed: 4.2ms preprocess, 2439.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 13 cars, 2430.7ms
# Speed: 4.3ms preprocess, 2430.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 14 cars, 3489.2ms
# Speed: 4.1ms preprocess, 3489.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 17 cars, 2591.7ms
# Speed: 3.9ms preprocess, 2591.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 2405.7ms
# Speed: 6.3ms preprocess, 2405.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 2432.7ms
# Speed: 3.8ms preprocess, 2432.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 2427.6ms
# Speed: 4.0ms preprocess, 2427.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 17 cars, 3679.9ms
# Speed: 4.1ms preprocess, 3679.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 2416.7ms
# Speed: 10.4ms preprocess, 2416.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 2468.9ms
# Speed: 4.1ms preprocess, 2468.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 2454.3ms
# Speed: 4.4ms preprocess, 2454.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 2686.9ms
# Speed: 3.8ms preprocess, 2686.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 15 cars, 3389.9ms
# Speed: 7.1ms preprocess, 3389.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 2437.3ms
# Speed: 5.7ms preprocess, 2437.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 14 cars, 2452.1ms
# Speed: 4.4ms preprocess, 2452.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 2437.4ms
# Speed: 4.1ms preprocess, 2437.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 15 cars, 3044.2ms
# Speed: 4.0ms preprocess, 3044.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 3059.5ms
# Speed: 4.7ms preprocess, 3059.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 15 cars, 2461.4ms
# Speed: 4.4ms preprocess, 2461.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 2447.4ms
# Speed: 4.0ms preprocess, 2447.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 17 cars, 2440.7ms
# Speed: 7.2ms preprocess, 2440.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 17 cars, 3491.2ms
# Speed: 4.8ms preprocess, 3491.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 2561.3ms
# Speed: 8.1ms preprocess, 2561.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 2440.4ms
# Speed: 4.0ms preprocess, 2440.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 2399.9ms
# Speed: 4.2ms preprocess, 2399.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 15 cars, 2423.5ms
# Speed: 4.0ms preprocess, 2423.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 3650.2ms
# Speed: 4.0ms preprocess, 3650.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 2459.6ms
# Speed: 3.9ms preprocess, 2459.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 15 cars, 2416.1ms
# Speed: 4.1ms preprocess, 2416.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 14 cars, 2427.1ms
# Speed: 3.8ms preprocess, 2427.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 15 cars, 2631.9ms
# Speed: 3.2ms preprocess, 2631.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 15 cars, 3417.6ms
# Speed: 4.2ms preprocess, 3417.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 13 cars, 2424.8ms
# Speed: 3.9ms preprocess, 2424.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 15 cars, 2436.8ms
# Speed: 4.1ms preprocess, 2436.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 14 cars, 2395.7ms
# Speed: 4.1ms preprocess, 2395.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 13 cars, 2944.6ms
# Speed: 4.1ms preprocess, 2944.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 14 cars, 3142.7ms
# Speed: 5.3ms preprocess, 3142.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 14 cars, 2444.6ms
# Speed: 4.3ms preprocess, 2444.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 14 cars, 2432.0ms
# Speed: 3.9ms preprocess, 2432.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 14 cars, 2433.1ms
# Speed: 4.2ms preprocess, 2433.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 14 cars, 3332.0ms
# Speed: 4.0ms preprocess, 3332.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 14 cars, 2602.9ms
# Speed: 4.0ms preprocess, 2602.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 14 cars, 2429.5ms
# Speed: 3.9ms preprocess, 2429.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 13 cars, 2451.4ms
# Speed: 5.2ms preprocess, 2451.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 15 cars, 2416.9ms
# Speed: 4.9ms preprocess, 2416.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 17 cars, 3665.0ms
# Speed: 4.1ms preprocess, 3665.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 17 cars, 2475.6ms
# Speed: 6.3ms preprocess, 2475.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 17 cars, 2472.9ms
# Speed: 4.5ms preprocess, 2472.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 17 cars, 2460.3ms
# Speed: 4.0ms preprocess, 2460.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 15 cars, 2647.8ms
# Speed: 3.9ms preprocess, 2647.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 15 cars, 3392.5ms
# Speed: 4.2ms preprocess, 3392.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 14 cars, 2430.5ms
# Speed: 3.1ms preprocess, 2430.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 15 cars, 2433.8ms
# Speed: 6.1ms preprocess, 2433.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 15 cars, 2407.5ms
# Speed: 4.6ms preprocess, 2407.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 3009.3ms
# Speed: 4.2ms preprocess, 3009.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 3056.0ms
# Speed: 4.4ms preprocess, 3056.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 16 cars, 2430.1ms
# Speed: 4.2ms preprocess, 2430.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 15 cars, 2412.6ms
# Speed: 4.1ms preprocess, 2412.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 15 cars, 2429.7ms
# Speed: 4.0ms preprocess, 2429.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 15 cars, 3389.1ms
# Speed: 3.9ms preprocess, 3389.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# ## Save and Submit Your Work

# %% [markdown]
# Submit both the notebook and the output video

# %%
cap.release()
video_writer.release()
cv2.destroyAllWindows()

# %% [markdown]
# Process taking too long

# %% [markdown]
# #Source:
# * https://learnopencv.com/yolov8-object-tracking-and-counting-with-opencv/
# * https://docs.ultralytics.com/guides/object-counting/
# * https://github.com/orgs/ultralytics/discussions/6738
# * https://github.com/arpitmaur07/Object-Detection-and-Object-Counting/blob/main/main.py
# * https://github.com/roboflow/notebooks/blob/main/notebooks/how-to-track-and-count-vehicles-with-yolov8.ipynb
